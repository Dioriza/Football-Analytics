# %% [markdown]
# # Package Installation

# %%
pip install mplsoccer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
from mplsoccer import add_image, FontManager
from mplsoccer import Pitch

# %% [markdown]
# # Data Preparation

# %%
raw = '''{"shotmap":[{"player":{"name":"Jack Fletcher","firstName":"Jack Fletcher","slug":"jack-fletcher","shortName":"J. Fletcher","position":"M","jerseyNumber":"38","userCount":4332,"gender":"M","id":1402726,"fieldTranslations":{"nameTranslation":{"ar":"جاك فليتشر","hi":"जैक फ्लेचर","bn":"জ্যাক ফ্লেচার"},"shortNameTranslation":{"ar":"ج. فليتشر","hi":"जे. फ्लेचर","bn":"জে. ফ্লেচার"}}},"isHome":true,"shotType":"miss","situation":"corner","playerCoordinates":{"x":18.2,"y":44.2,"z":0},"bodyPart":"left-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":50.6,"z":97.2},"xg":0.034750040620565,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436710,"time":90,"addedTime":4,"timeSeconds":5582,"draw":{"start":{"x":44.2,"y":18.2},"end":{"x":49.4,"y":0},"goal":{"x":49.4,"y":2.8}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":718,"periodTimeSeconds":182,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"save","situation":"assisted","playerCoordinates":{"x":13.4,"y":51.9,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-left","goalMouthCoordinates":{"x":0,"y":52.9,"z":1.3},"blockCoordinates":{"x":2.2,"y":49.8,"z":0},"xg":0.085299305617809,"xgot":0.2569907605648,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436658,"time":90,"timeSeconds":5370,"draw":{"start":{"x":51.9,"y":13.4},"block":{"x":49.8,"y":2.2},"end":{"x":47.1,"y":0},"goal":{"x":47.1,"y":98.7}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":30,"periodTimeSeconds":2670,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"save","situation":"assisted","playerCoordinates":{"x":10.8,"y":47.5,"z":0},"bodyPart":"head","goalMouthLocation":"high-right","goalMouthCoordinates":{"x":0,"y":47.2,"z":24.7},"blockCoordinates":{"x":1.9,"y":49.6,"z":0},"xg":0.055763140320778,"xgot":0.26167058944702,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436639,"time":83,"timeSeconds":4925,"draw":{"start":{"x":47.5,"y":10.8},"block":{"x":49.6,"y":1.9},"end":{"x":52.8,"y":0},"goal":{"x":52.8,"y":75.3}},"reversedPeriodTime":8,"reversedPeriodTimeSeconds":475,"periodTimeSeconds":2225,"incidentType":"shot"},{"player":{"name":"Ladislav Krejčí","slug":"ladislav-krejci","shortName":"L. Krejčí","position":"D","jerseyNumber":"37","userCount":2117,"gender":"M","id":856250,"fieldTranslations":{"nameTranslation":{"ar":"لاديسلاف كريتشي","hi":"लादिस्लाव क्रेजी","bn":"লাদিস্লাভ ক্রেজচি"},"shortNameTranslation":{"ar":"ل. كريتشي","hi":"एल. क्रेजी","bn":"এল. ক্রেজচি"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":14,"y":48.4,"z":0},"bodyPart":"head","goalMouthLocation":"right","goalMouthCoordinates":{"x":0,"y":7.4,"z":11.1},"blockCoordinates":{"x":9.9,"y":57.8,"z":0},"xg":0.019741132855415,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436638,"time":81,"timeSeconds":4843,"draw":{"start":{"x":48.4,"y":14},"block":{"x":57.8,"y":9.9},"end":{"x":92.6,"y":0},"goal":{"x":92.6,"y":88.9}},"reversedPeriodTime":10,"reversedPeriodTimeSeconds":557,"periodTimeSeconds":2143,"incidentType":"shot"},{"player":{"name":"Jhon Arias","firstName":"","lastName":"","slug":"jhon-arias","shortName":"J. Arias","position":"M","jerseyNumber":"10","userCount":27455,"gender":"M","sofascoreId":"jhonariasa","id":844096,"fieldTranslations":{"nameTranslation":{"ar":"جون أرياس","hi":"जॉन एरियास","bn":"জন আরিয়াস"},"shortNameTranslation":{"ar":"ج. أرياس","hi":"जे. एरियास","bn":"জে. আরিয়াস"}}},"isHome":false,"shotType":"block","situation":"assisted","playerCoordinates":{"x":19.8,"y":53.2,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":51.4,"z":19},"blockCoordinates":{"x":17.8,"y":52.7,"z":0},"xg":0.033011101186275,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436636,"time":79,"timeSeconds":4735,"draw":{"start":{"x":53.2,"y":19.8},"block":{"x":52.7,"y":17.8},"end":{"x":48.6,"y":0},"goal":{"x":48.6,"y":81}},"reversedPeriodTime":12,"reversedPeriodTimeSeconds":665,"periodTimeSeconds":2035,"incidentType":"shot"},{"player":{"name":"Matheus Cunha","slug":"matheus-cunha","shortName":"M. Cunha","position":"F","jerseyNumber":"10","userCount":62321,"gender":"M","sofascoreId":"Cunha","id":886363,"fieldTranslations":{"nameTranslation":{"ar":"ماثيوس كونيا","hi":"मैथियस कुन्हा","bn":"ম্যাথিউস কুনহা"},"shortNameTranslation":{"ar":"م. كونيا","hi":"एम. कुन्हा","bn":"এম. কুনহা"}}},"isHome":true,"shotType":"block","situation":"assisted","playerCoordinates":{"x":19.4,"y":63.8,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.9,"z":19},"blockCoordinates":{"x":15,"y":60.5,"z":0},"xg":0.057863757014275,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436635,"time":78,"timeSeconds":4649,"draw":{"start":{"x":63.8,"y":19.4},"block":{"x":60.5,"y":15},"end":{"x":49.1,"y":0},"goal":{"x":49.1,"y":81}},"reversedPeriodTime":13,"reversedPeriodTimeSeconds":751,"periodTimeSeconds":1949,"incidentType":"shot"},{"player":{"name":"Patrick Dorgu","firstName":"","lastName":"","slug":"dorgu-patrick","shortName":"P. Dorgu","position":"M","jerseyNumber":"13","userCount":14880,"gender":"M","sofascoreId":"Odogwu","id":1397168,"fieldTranslations":{"nameTranslation":{"ar":"دورغو، باتريك","hi":"डोर्गू, पैट्रिक","bn":"ডরগু, প্যাট্রিক"},"shortNameTranslation":{"ar":"ب. دورغو","hi":"पी. डोर्गू","bn":"পি. ডরগু"}}},"isHome":true,"shotType":"block","situation":"assisted","playerCoordinates":{"x":24.7,"y":44.4,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":51,"z":19},"blockCoordinates":{"x":20.3,"y":46,"z":0},"xg":0.028109900653362,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436539,"time":69,"timeSeconds":4097,"draw":{"start":{"x":44.4,"y":24.7},"block":{"x":46,"y":20.3},"end":{"x":49,"y":0},"goal":{"x":49,"y":81}},"reversedPeriodTime":22,"reversedPeriodTimeSeconds":1303,"periodTimeSeconds":1397,"incidentType":"shot"},{"player":{"name":"Manuel Ugarte","slug":"manuel-ugarte","shortName":"M. Ugarte","position":"M","jerseyNumber":"25","userCount":18991,"gender":"M","sofascoreId":"ugartemanu","id":846425,"fieldTranslations":{"nameTranslation":{"ar":"مانويل أوغارتي","hi":"मैनुअल उगार्टे","bn":"ম্যানুয়েল উগার্তে"},"shortNameTranslation":{"ar":"م. أوغارتي","hi":"एम. उगार्टे","bn":"এম. উগার্তে"}}},"isHome":true,"shotType":"save","situation":"regular","playerCoordinates":{"x":27.5,"y":52.8,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high-centre","goalMouthCoordinates":{"x":0,"y":50,"z":29.1},"blockCoordinates":{"x":2,"y":50.4,"z":0},"xg":0.027509476989508,"xgot":0.0095192836597562,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436532,"time":65,"timeSeconds":3886,"draw":{"start":{"x":52.8,"y":27.5},"block":{"x":50.4,"y":2},"end":{"x":50,"y":0},"goal":{"x":50,"y":70.9}},"reversedPeriodTime":26,"reversedPeriodTimeSeconds":1514,"periodTimeSeconds":1186,"incidentType":"shot"},{"player":{"name":"Yerson Mosquera","slug":"yerson-mosquera","shortName":"Y. Mosquera","position":"D","jerseyNumber":"15","userCount":2992,"gender":"M","id":1014835,"fieldTranslations":{"nameTranslation":{"ar":"يرسون موسكيرا","hi":"यर्सन मॉस्केरा","bn":"ইয়ারসন মস্কেরা"},"shortNameTranslation":{"ar":"ي. موسكيرا","hi":"वाई. मॉस्केरा","bn":"ওয়াই. মস্কেরা"}}},"isHome":false,"shotType":"miss","situation":"regular","playerCoordinates":{"x":3,"y":50.3,"z":0},"bodyPart":"right-foot","goalMouthLocation":"close-right","goalMouthCoordinates":{"x":0,"y":43.4,"z":8.3},"xg":0.51764369010925,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436537,"time":64,"timeSeconds":3785,"draw":{"start":{"x":50.3,"y":3},"end":{"x":56.6,"y":0},"goal":{"x":56.6,"y":91.7}},"reversedPeriodTime":27,"reversedPeriodTimeSeconds":1615,"periodTimeSeconds":1085,"incidentType":"shot"},{"player":{"name":"Ladislav Krejčí","slug":"ladislav-krejci","shortName":"L. Krejčí","position":"D","jerseyNumber":"37","userCount":2117,"gender":"M","id":856250,"fieldTranslations":{"nameTranslation":{"ar":"لاديسلاف كريتشي","hi":"लादिस्लाव क्रेजी","bn":"লাদিস্লাভ ক্রেজচি"},"shortNameTranslation":{"ar":"ل. كريتشي","hi":"एल. क्रेजी","bn":"এল. ক্রেজচি"}}},"isHome":false,"shotType":"save","situation":"assisted","playerCoordinates":{"x":10.8,"y":42.8,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":48.8,"z":1.3},"blockCoordinates":{"x":0.90000000000001,"y":47.7,"z":0},"xg":0.24982604384422,"xgot":0.35086289048195,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436529,"time":64,"timeSeconds":3784,"draw":{"start":{"x":42.8,"y":10.8},"block":{"x":47.7,"y":0.90000000000001},"end":{"x":51.2,"y":0},"goal":{"x":51.2,"y":98.7}},"reversedPeriodTime":27,"reversedPeriodTimeSeconds":1616,"periodTimeSeconds":1084,"incidentType":"shot"},{"player":{"name":"Yerson Mosquera","slug":"yerson-mosquera","shortName":"Y. Mosquera","position":"D","jerseyNumber":"15","userCount":2992,"gender":"M","id":1014835,"fieldTranslations":{"nameTranslation":{"ar":"يرسون موسكيرا","hi":"यर्सन मॉस्केरा","bn":"ইয়ারসন মস্কেরা"},"shortNameTranslation":{"ar":"ي. موسكيرا","hi":"वाई. मॉस्केरा","bn":"ওয়াই. মস্কেরা"}}},"isHome":false,"shotType":"block","situation":"corner","playerCoordinates":{"x":7.5,"y":39.3,"z":0},"bodyPart":"head","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.2,"z":19},"blockCoordinates":{"x":5.9,"y":41.5,"z":0},"xg":0.021359933540225,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436520,"time":60,"timeSeconds":3573,"draw":{"start":{"x":39.3,"y":7.5},"block":{"x":41.5,"y":5.9},"end":{"x":49.8,"y":0},"goal":{"x":49.8,"y":81}},"reversedPeriodTime":31,"reversedPeriodTimeSeconds":1827,"periodTimeSeconds":873,"incidentType":"shot"},{"player":{"name":"Diogo Dalot","firstName":"","lastName":"","slug":"diogo-dalot","shortName":"D. Dalot","position":"M","jerseyNumber":"2","userCount":22662,"gender":"M","sofascoreId":"DDalot","id":843200,"fieldTranslations":{"nameTranslation":{"ar":"ديوغو دالوت","hi":"डिओगो डालोत","bn":"ডিওগো ডালট"},"shortNameTranslation":{"ar":"د. دالوت","hi":"डी. डालोत","bn":"ডি. ডালট"}}},"isHome":true,"shotType":"miss","situation":"corner","playerCoordinates":{"x":8.3,"y":41.1,"z":0},"bodyPart":"head","goalMouthLocation":"high-left","goalMouthCoordinates":{"x":0,"y":62.4,"z":50},"xg":0.018858535215259,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436369,"time":54,"timeSeconds":3204,"draw":{"start":{"x":41.1,"y":8.3},"end":{"x":37.6,"y":0},"goal":{"x":37.6,"y":50}},"reversedPeriodTime":37,"reversedPeriodTimeSeconds":2196,"periodTimeSeconds":504,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"save","situation":"assisted","playerCoordinates":{"x":9.7,"y":54,"z":0},"bodyPart":"head","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":49.7,"z":18.4},"blockCoordinates":{"x":0.7,"y":50.2,"z":0},"xg":0.090269945561886,"xgot":0.022774465382099,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436365,"time":53,"timeSeconds":3139,"draw":{"start":{"x":54,"y":9.7},"block":{"x":50.2,"y":0.7},"end":{"x":50.3,"y":0},"goal":{"x":50.3,"y":81.6}},"reversedPeriodTime":38,"reversedPeriodTimeSeconds":2261,"periodTimeSeconds":439,"incidentType":"shot"},{"player":{"name":"Ayden Heaven","firstName":"Ayden Heaven","slug":"heaven-ayden","shortName":"A. Heaven","position":"D","jerseyNumber":"26","userCount":9193,"gender":"M","id":1445799,"fieldTranslations":{"nameTranslation":{"ar":"هيفين، آيدن","hi":"हेवेन, आइडेन","bn":"হ্যাভেন, আইডেন"},"shortNameTranslation":{"ar":"أ. آيدن","hi":"ए. हेवेन","bn":"এ. হ্যাভেন"}}},"isHome":true,"shotType":"block","situation":"assisted","playerCoordinates":{"x":15.1,"y":61,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":51.6,"z":19},"blockCoordinates":{"x":13.5,"y":59.7,"z":0},"xg":0.043773077428341,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436367,"time":53,"timeSeconds":3131,"draw":{"start":{"x":61,"y":15.1},"block":{"x":59.7,"y":13.5},"end":{"x":48.4,"y":0},"goal":{"x":48.4,"y":81}},"reversedPeriodTime":38,"reversedPeriodTimeSeconds":2269,"periodTimeSeconds":431,"incidentType":"shot"},{"player":{"name":"Matheus Cunha","slug":"matheus-cunha","shortName":"M. Cunha","position":"F","jerseyNumber":"10","userCount":62321,"gender":"M","sofascoreId":"Cunha","id":886363,"fieldTranslations":{"nameTranslation":{"ar":"ماثيوس كونيا","hi":"मैथियस कुन्हा","bn":"ম্যাথিউস কুনহা"},"shortNameTranslation":{"ar":"م. كونيا","hi":"एम. कुन्हा","bn":"এম. কুনহা"}}},"isHome":true,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":15.3,"y":54,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high-left","goalMouthCoordinates":{"x":0,"y":62.9,"z":65.3},"xg":0.056838538497686,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436360,"time":51,"timeSeconds":3032,"draw":{"start":{"x":54,"y":15.3},"end":{"x":37.1,"y":0},"goal":{"x":37.1,"y":34.7}},"reversedPeriodTime":40,"reversedPeriodTimeSeconds":2368,"periodTimeSeconds":332,"incidentType":"shot"},{"player":{"name":"Ladislav Krejčí","slug":"ladislav-krejci","shortName":"L. Krejčí","position":"D","jerseyNumber":"37","userCount":2117,"gender":"M","id":856250,"fieldTranslations":{"nameTranslation":{"ar":"لاديسلاف كريتشي","hi":"लादिस्लाव क्रेजी","bn":"লাদিস্লাভ ক্রেজচি"},"shortNameTranslation":{"ar":"ل. كريتشي","hi":"एल. क्रेजी","bn":"এল. ক্রেজচি"}}},"isHome":false,"shotType":"goal","goalType":"regular","situation":"corner","playerCoordinates":{"x":6.9,"y":42.3,"z":0},"bodyPart":"head","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":46.6,"z":12},"xg":0.066580347716808,"xgot":0.4548377096653,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436165,"time":45,"timeSeconds":2652,"draw":{"start":{"x":42.3,"y":6.9},"end":{"x":53.4,"y":0},"goal":{"x":53.4,"y":88}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":48,"periodTimeSeconds":2652,"incidentType":"shot"},{"player":{"name":"Mateus Mané","firstName":"Mateus Mané","slug":"mateus-mane","shortName":"M. Mané","position":"F","jerseyNumber":"36","userCount":755,"gender":"M","id":1899647,"fieldTranslations":{"nameTranslation":{"ar":"ماتيوس مانيه"},"shortNameTranslation":{"ar":"م. مانيه"}}},"isHome":false,"shotType":"save","situation":"regular","playerCoordinates":{"x":24.1,"y":40.9,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":47.7,"z":12.7},"blockCoordinates":{"x":2.2,"y":48.7,"z":0},"xg":0.040291849523783,"xgot":0.067981876432896,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436143,"time":41,"timeSeconds":2449,"draw":{"start":{"x":40.9,"y":24.1},"block":{"x":48.7,"y":2.2},"end":{"x":52.3,"y":0},"goal":{"x":52.3,"y":87.3}},"reversedPeriodTime":5,"reversedPeriodTimeSeconds":251,"periodTimeSeconds":2449,"incidentType":"shot"},{"player":{"name":"Hugo Bueno","firstName":"","lastName":"","slug":"hugo-bueno","shortName":"H. Bueno","position":"D","jerseyNumber":"3","userCount":660,"gender":"M","id":1013928,"fieldTranslations":{"nameTranslation":{"ar":"هوغو بوينو","hi":"ह्यूगो ब्यूनो","bn":"হুগো বুয়েনো"},"shortNameTranslation":{"ar":"ه. بوينو","hi":"एच. ब्यूनो","bn":"এইচ. বুয়েনো"}}},"isHome":false,"shotType":"save","situation":"assisted","playerCoordinates":{"x":4.5,"y":34.3,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.1,"z":1.3},"blockCoordinates":{"x":0.7,"y":45.1,"z":0},"xg":0.084853284060955,"xgot":0.14671109616756,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436146,"time":41,"timeSeconds":2448,"draw":{"start":{"x":34.3,"y":4.5},"block":{"x":45.1,"y":0.7},"end":{"x":49.9,"y":0},"goal":{"x":49.9,"y":98.7}},"reversedPeriodTime":5,"reversedPeriodTimeSeconds":252,"periodTimeSeconds":2448,"incidentType":"shot"},{"player":{"name":"Tolu Arokodare","slug":"tolu-arokodare","shortName":"T. Arokodare","position":"F","jerseyNumber":"14","userCount":5726,"gender":"M","id":987734,"fieldTranslations":{"nameTranslation":{"ar":"تولو أروكوداري","hi":"तोलु अरोकोदारे","bn":"তিন অরোকোডারে"},"shortNameTranslation":{"ar":"ت. أروكوداري","hi":"टी. अरोकोदारे","bn":"টি. অরোকোডারে"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":8.4,"y":48.6,"z":0},"bodyPart":"head","goalMouthLocation":"close-high","goalMouthCoordinates":{"x":0,"y":48.4,"z":59.7},"xg":0.13739775121212,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436134,"time":40,"timeSeconds":2360,"draw":{"start":{"x":48.6,"y":8.4},"end":{"x":51.6,"y":0},"goal":{"x":51.6,"y":40.3}},"reversedPeriodTime":6,"reversedPeriodTimeSeconds":340,"periodTimeSeconds":2360,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"post","situation":"corner","playerCoordinates":{"x":2.9,"y":41.7,"z":0},"bodyPart":"head","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":55.3,"z":19.6},"xg":0.12257669866085,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436128,"time":38,"timeSeconds":2276,"draw":{"start":{"x":41.7,"y":2.9},"end":{"x":44.7,"y":0},"goal":{"x":44.7,"y":80.4}},"reversedPeriodTime":8,"reversedPeriodTimeSeconds":424,"periodTimeSeconds":2276,"incidentType":"shot"},{"player":{"name":"Patrick Dorgu","firstName":"","lastName":"","slug":"dorgu-patrick","shortName":"P. Dorgu","position":"M","jerseyNumber":"13","userCount":14880,"gender":"M","sofascoreId":"Odogwu","id":1397168,"fieldTranslations":{"nameTranslation":{"ar":"دورغو، باتريك","hi":"डोर्गू, पैट्रिक","bn":"ডরগু, প্যাট্রিক"},"shortNameTranslation":{"ar":"ب. دورغو","hi":"पी. डोर्गू","bn":"পি. ডরগু"}}},"isHome":true,"shotType":"block","situation":"assisted","playerCoordinates":{"x":16.5,"y":29.2,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-left","goalMouthCoordinates":{"x":0,"y":52.8,"z":19},"blockCoordinates":{"x":10.9,"y":35.4,"z":0},"xg":0.047036115080118,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436127,"time":38,"timeSeconds":2226,"draw":{"start":{"x":29.2,"y":16.5},"block":{"x":35.4,"y":10.9},"end":{"x":47.2,"y":0},"goal":{"x":47.2,"y":81}},"reversedPeriodTime":8,"reversedPeriodTimeSeconds":474,"periodTimeSeconds":2226,"incidentType":"shot"},{"player":{"name":"Hee-Chan Hwang","slug":"hee-chan-hwang","shortName":"H. Hwang","position":"F","jerseyNumber":"11","userCount":6494,"gender":"M","sofascoreId":"Hwangso","id":786186,"fieldTranslations":{"nameTranslation":{"ar":"هي تشان هوانغ","hi":"ही-चान ह्वांग","bn":"হি-চ্যান হোয়াং"},"shortNameTranslation":{"ar":"ه. هوانغ","hi":"एच. ह्वांग","bn":"এইচ. হোয়াং"}}},"isHome":false,"shotType":"miss","situation":"set-piece","playerCoordinates":{"x":18.4,"y":50.5,"z":0},"bodyPart":"right-foot","goalMouthLocation":"close-high-right","goalMouthCoordinates":{"x":0,"y":41.7,"z":45.8},"xg":0.057171992957592,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6436020,"time":35,"timeSeconds":2097,"draw":{"start":{"x":50.5,"y":18.4},"end":{"x":58.3,"y":0},"goal":{"x":58.3,"y":54.2}},"reversedPeriodTime":11,"reversedPeriodTimeSeconds":603,"periodTimeSeconds":2097,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"save","situation":"assisted","playerCoordinates":{"x":10.1,"y":49.3,"z":0},"bodyPart":"head","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.2,"z":15.2},"blockCoordinates":{"x":1.8,"y":49.8,"z":0},"xg":0.056447006762028,"xgot":0.01857827603817,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436016,"time":33,"timeSeconds":1972,"draw":{"start":{"x":49.3,"y":10.1},"block":{"x":49.8,"y":1.8},"end":{"x":49.8,"y":0},"goal":{"x":49.8,"y":84.8}},"reversedPeriodTime":13,"reversedPeriodTimeSeconds":728,"periodTimeSeconds":1972,"incidentType":"shot"},{"player":{"name":"Joshua Zirkzee","slug":"joshua-zirkzee","shortName":"J. Zirkzee","position":"F","jerseyNumber":"11","userCount":26429,"gender":"M","sofascoreId":"JZirkzee","id":917007,"fieldTranslations":{"nameTranslation":{"ar":"جوشوا زيركزي","hi":"जोशुआ ज़िर्कज़ी","bn":"জোশুয়া জিরকজি"},"shortNameTranslation":{"ar":"ج. زيركزي","hi":"जे. ज़िर्कज़ी","bn":"জে. জিরকজি"}}},"isHome":true,"shotType":"goal","goalType":"regular","situation":"regular","playerCoordinates":{"x":17.2,"y":49.8,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":51.1,"z":5.7},"xg":0.087609678506851,"xgot":0.15805140137672,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6436006,"time":27,"timeSeconds":1585,"draw":{"start":{"x":49.8,"y":17.2},"end":{"x":48.9,"y":0},"goal":{"x":48.9,"y":94.3}},"reversedPeriodTime":19,"reversedPeriodTimeSeconds":1115,"periodTimeSeconds":1585,"incidentType":"shot"},{"player":{"name":"Hee-Chan Hwang","slug":"hee-chan-hwang","shortName":"H. Hwang","position":"F","jerseyNumber":"11","userCount":6494,"gender":"M","sofascoreId":"Hwangso","id":786186,"fieldTranslations":{"nameTranslation":{"ar":"هي تشان هوانغ","hi":"ही-चान ह्वांग","bn":"হি-চ্যান হোয়াং"},"shortNameTranslation":{"ar":"ه. هوانغ","hi":"एच. ह्वांग","bn":"এইচ. হোয়াং"}}},"isHome":false,"shotType":"miss","situation":"regular","playerCoordinates":{"x":14.8,"y":37.8,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":48.4,"z":68.1},"xg":0.06700948625803,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25217,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"سيني لامينس","hi":"सेने लामेन्स","bn":"সেনে ল্যামেনস"},"shortNameTranslation":{"ar":"س. لامينس","hi":"एस. लामेन्स","bn":"এস. ল্যামেনস"}}},"id":6435899,"time":20,"timeSeconds":1151,"draw":{"start":{"x":37.8,"y":14.8},"end":{"x":51.6,"y":0},"goal":{"x":51.6,"y":31.9}},"reversedPeriodTime":26,"reversedPeriodTimeSeconds":1549,"periodTimeSeconds":1151,"incidentType":"shot"},{"player":{"name":"Benjamin Šeško","slug":"benjamin-sesko","shortName":"B. Šeško","position":"F","jerseyNumber":"30","userCount":71389,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"بنجامين سيسكو","hi":"बेंजामिन सेस्को","bn":"বেঞ্জামিন শেস্কো"},"shortNameTranslation":{"ar":"ب. سيسكو","hi":"बी. सेस्को","bn":"বি. শেস্কো"}}},"isHome":true,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":10.7,"y":31.6,"z":0},"bodyPart":"right-foot","goalMouthLocation":"right","goalMouthCoordinates":{"x":0,"y":39,"z":6.9},"xg":0.024786630645394,"xgot":0,"goalkeeper":{"name":"José Sá","slug":"jose-sa","shortName":"J. Sá","position":"G","jerseyNumber":"1","userCount":3999,"gender":"M","id":252669,"fieldTranslations":{"nameTranslation":{"ar":"جوزيه سا","hi":"जोस सा","bn":"জোসে সা"},"shortNameTranslation":{"ar":"ج. سا","hi":"जे. सा","bn":"জে. সা"}}},"id":6435865,"time":15,"timeSeconds":846,"draw":{"start":{"x":31.6,"y":10.7},"end":{"x":61,"y":0},"goal":{"x":61,"y":93.1}},"reversedPeriodTime":31,"reversedPeriodTimeSeconds":1854,"periodTimeSeconds":846,"incidentType":"shot"}]}'''

# %%
data = json.loads(raw)

df = pd.json_normalize(data["shotmap"])

df = df[[
    "player.name",
    "player.position",
    "isHome",
    "shotType",
    "situation",
    "bodyPart",
    "xg",
    "xgot",
    "time",
    "timeSeconds",
    "playerCoordinates.x",
    "playerCoordinates.y"
]]

df.head()
# Out:
#        player.name player.position  isHome shotType situation    bodyPart  \
# 0    Jack Fletcher               M    True     miss    corner   left-foot
# 1   Benjamin Šeško               F    True     save  assisted  right-foot
# 2   Benjamin Šeško               F    True     save  assisted        head
# 3  Ladislav Krejčí               D   False     miss  assisted        head
# 4       Jhon Arias               M   False    block  assisted  right-foot
#
#          xg      xgot  time  timeSeconds  playerCoordinates.x  \
# 0  0.034750  0.000000    90         5582                 18.2
# 1  0.085299  0.256991    90         5370                 13.4
# 2  0.055763  0.261671    83         4925                 10.8
# 3  0.019741  0.000000    81         4843                 14.0
# 4  0.033011  0.000000    79         4735                 19.8
#
#    playerCoordinates.y
# 0                 44.2
# 1                 51.9
# 2                 47.5
# 3                 48.4
# 4                 53.2

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Expected Goals (xG) Ratio

# %%
player_stats = (
    df
    .groupby("player.name")
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        total_xgot=("xgot", "sum")
    )
    .reset_index()
)

# finishing ratio quality
player_stats["xgot_ratio"] = player_stats["total_xgot"] / player_stats["total_xg"]

player_stats.sort_values("total_xg", ascending=False)
# Out:
#         player.name  shots  total_xg  total_xgot  xgot_ratio
# 14  Yerson Mosquera      2  0.539004    0.000000    0.000000
# 1    Benjamin Šeško      6  0.435143    0.560014    1.286966
# 8   Ladislav Krejčí      3  0.336148    0.805701    2.396866
# 13   Tolu Arokodare      1  0.137398    0.000000    0.000000
# 3    Hee-Chan Hwang      2  0.124181    0.000000    0.000000
# 11    Matheus Cunha      2  0.114702    0.000000    0.000000
# 7    Joshua Zirkzee      1  0.087610    0.158051    1.804040
# 4        Hugo Bueno      1  0.084853    0.146711    1.728997
# 12    Patrick Dorgu      2  0.075146    0.000000    0.000000
# 0      Ayden Heaven      1  0.043773    0.000000    0.000000
# 10      Mateus Mané      1  0.040292    0.067982    1.687236
# 5     Jack Fletcher      1  0.034750    0.000000    0.000000
# 6        Jhon Arias      1  0.033011    0.000000    0.000000
# 9     Manuel Ugarte      1  0.027509    0.009519    0.346037
# ...

# %%
# 2 shot minimum filter
player_stats = player_stats[player_stats["shots"] >= 2]
MIN_XG = 0.2
MIN_SHOTS = 2

# %%
# Most Dangerous Players
most_dangerous = (
    player_stats
    .query("total_xg >= @MIN_XG and shots >= @MIN_SHOTS")
    .sort_values("xgot_ratio", ascending=False)
    .head(3)
)


# Most Wasteful Players
most_wasteful = (
    player_stats
    .query("total_xg >= @MIN_XG and shots >= @MIN_SHOTS")
    .sort_values("xgot_ratio", ascending=True)
    .head(3)
)

# %%
most_dangerous
# Out:
#         player.name  shots  total_xg  total_xgot  xgot_ratio
# 8   Ladislav Krejčí      3  0.336148    0.805701    2.396866
# 1    Benjamin Šeško      6  0.435143    0.560014    1.286966
# 14  Yerson Mosquera      2  0.539004    0.000000    0.000000

# %%
most_wasteful
# Out:
#         player.name  shots  total_xg  total_xgot  xgot_ratio
# 14  Yerson Mosquera      2  0.539004    0.000000    0.000000
# 1    Benjamin Šeško      6  0.435143    0.560014    1.286966
# 8   Ladislav Krejčí      3  0.336148    0.805701    2.396866

# %%
plt.style.use("dark_background")

fig, ax = plt.subplots(figsize=(10, 7))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

# ===============================
# Base color logic
# ===============================
colors = np.where(
    player_stats["xgot_ratio"] > 1.2, "#2ecc71",
    np.where(player_stats["xgot_ratio"] < 0.6, "#e74c3c", "#95a5a6")
)

# ===============================
# Override: Ladislav Krejčí (goal scorer)
# ===============================
is_krejci = player_stats["player.name"] == "Ladislav Krejčí"
colors[is_krejci] = "#f1c40f"  # gold

# ===============================
# Scatter
# ===============================
ax.scatter(
    player_stats["total_xg"],
    player_stats["total_xgot"],
    s=player_stats["shots"] * 220,
    c=colors,
    alpha=0.9,
    edgecolor="white",
    linewidth=np.where(is_krejci, 1.8, 0.7)  # highlight Krejčí
)

# ===============================
# Reference line
# ===============================
max_val = max(
    player_stats["total_xg"].max(),
    player_stats["total_xgot"].max()
)

ax.plot(
    [0, max_val],
    [0, max_val],
    linestyle="--",
    color="#f1c40f",
    linewidth=1,
    alpha=0.8
)

# ===============================
# Annotations (extremes + Krejčí)
# ===============================
for _, row in player_stats.iterrows():
    if (
        row["xgot_ratio"] < 0.6
        or row["xgot_ratio"] > 1.2
        or row["player.name"] == "Ladislav Krejčí"
    ):
        ax.annotate(
            row["player.name"],
            (row["total_xg"], row["total_xgot"]),
            xytext=(6, 6),
            textcoords="offset points",
            fontsize=9,
            color="white"
        )

# ===============================
# Quadrant Labels
# ===============================
ax.text(
    max_val * 0.75, max_val * 0.9,
    "🔥 DEADLY FINISHER\nHigh xG | High xGOT",
    fontsize=10, color="#2ecc71", ha="center", va="center"
)

ax.text(
    max_val * 0.75, max_val * 0.25,
    "❌ WASTEFUL\nHigh xG | Low xGOT",
    fontsize=10, color="#e74c3c", ha="center", va="center"
)

ax.text(
    max_val * 0.25, max_val * 0.9,
    "🎯 CLINICAL\nLow xG | High xGOT",
    fontsize=10, color="#f1c40f", ha="center", va="center"
)

ax.text(
    max_val * 0.08, max_val * 0.08,
    "⚪ LOW IMPACT\nLow xG | Low xGOT",
    fontsize=10,
    color="#ecf0f1",
    ha="left", va="bottom",
    bbox=dict(boxstyle="round,pad=0.3", fc="#000000", ec="none", alpha=0.55)
)

# ===============================
# Legend (manual, clean)
# ===============================
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Dangerous finisher',
           markerfacecolor='#2ecc71', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Wasteful',
           markerfacecolor='#e74c3c', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Neutral',
           markerfacecolor='#95a5a6', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Goal scorer (Krejčí)',
           markerfacecolor='#f1c40f', markersize=10),
    Line2D([0], [0], linestyle='--', color='#f1c40f', label='xG = xGOT')
]

ax.legend(
    handles=legend_elements,
    loc="upper left",
    frameon=False,
    fontsize=9
)

# ===============================
# Labels & title
# ===============================
ax.set_xlabel("Total xG", fontsize=11, color="white")
ax.set_ylabel("Total xGOT", fontsize=11, color="white")

ax.set_title(
    "Dangerous vs Wasteful Players",
    fontsize=15,
    color="white",
    pad=14
)

# ===============================
# Grid & spines
# ===============================
ax.grid(color="white", alpha=0.08)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#666666")
ax.spines["bottom"].set_color("#666666")

plt.tight_layout()
plt.show()

# %%
# Top 6 based on xGOT
top6_xgot = (
    player_stats
    .sort_values("total_xgot", ascending=False)
    .head(6)
    .reset_index(drop=True)
)

top6_xgot
# Out:
#        player.name  shots  total_xg  total_xgot  xgot_ratio
# 0  Ladislav Krejčí      3  0.336148    0.805701    2.396866
# 1   Benjamin Šeško      6  0.435143    0.560014    1.286966
# 2   Hee-Chan Hwang      2  0.124181    0.000000    0.000000
# 3    Matheus Cunha      2  0.114702    0.000000    0.000000
# 4    Patrick Dorgu      2  0.075146    0.000000    0.000000
# 5  Yerson Mosquera      2  0.539004    0.000000    0.000000

# %%
plt.style.use("dark_background")

# Ambil Top 6 xGOT
top6_xgot = (
    player_stats
    .sort_values("total_xgot", ascending=False)
    .head(6)
    .reset_index(drop=True)
)

fig, ax = plt.subplots(figsize=(9, 6))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

# Warna: emas untuk Krejčí, abu-abu untuk lainnya
colors = [
    "#f1c40f" if name == "Ladislav Krejčí" else "#95a5a6"
    for name in top6_xgot["player.name"]
]

# Bar chart
bars = ax.barh(
    top6_xgot["player.name"],
    top6_xgot["total_xgot"],
    color=colors,
    edgecolor="white",
    alpha=0.9
)

# Value labels
for bar in bars:
    width = bar.get_width()
    ax.text(
        width + 0.02,
        bar.get_y() + bar.get_height() / 2,
        f"{width:.2f}",
        va="center",
        fontsize=10,
        color="white"
    )

# Invert y-axis (ranking)
ax.invert_yaxis()

# Labels & title
ax.set_xlabel("Total xGOT", fontsize=11)
ax.set_ylabel("")
ax.set_title(
    "Top 6 Players by Expected Goals on Target (xGOT)",
    fontsize=14,
    pad=12
)

# Grid & spines
ax.grid(axis="x", alpha=0.15)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#666666")
ax.spines["bottom"].set_color("#666666")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Shot Map

# %%
plt.scatter(
    df["playerCoordinates.y"],
    df["playerCoordinates.x"],
    c=df["xg"],
    cmap="Reds",
    s=df["xg"]*1000,
    alpha=0.7
)
plt.colorbar(label="xG")
plt.xlabel("Width")
plt.ylabel("Length")
plt.title("Shot Map based on  xG. United vs Wolves")
plt.show()

# %%
from mplsoccer import Pitch
import matplotlib.pyplot as plt

pitch = Pitch(
    pitch_type="opta",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, ax = pitch.draw(figsize=(10, 7))

# 👉 Batasi ke setengah lapangan kiri
ax.set_xlim(0, 50)

sc = pitch.scatter(
    df["playerCoordinates.x"],
    df["playerCoordinates.y"],
    s=df["xg"] * 3000,
    c=df["xgot"],
    cmap="viridis",
    edgecolors="white",
    linewidth=0.6,
    alpha=0.85,
    ax=ax
)

cbar = plt.colorbar(sc, ax=ax)
cbar.set_label("xGOT")

ax.set_title(
    "Shot Map \nBubble size = xG | Color = xGOT\nManchester United vs Wolverhampton",
    color="white",
    fontsize=14
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

ax.scatter(
    df["xg"],
    df["xgot"],
    alpha=0.75,
    edgecolor="white"
)

max_val = max(df["xg"].max(), df["xgot"].max())
ax.plot([0, max_val], [0, max_val], "--", color="#f1c40f")

ax.set_xlabel("xG")
ax.set_ylabel("xGOT")
ax.set_title("Shot Quality vs Placement", color="white")

plt.show()

# %% [markdown]
# ### Open Play vs Set-piece Chances

# %%
# Filter MU shots
mu = df[df["isHome"] == True]

open_play = mu[~mu["situation"].isin(["corner", "free_kick"])]
set_piece = mu[mu["situation"].isin(["corner", "free_kick"])]

pitch = Pitch(
    pitch_type="opta",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, axs = pitch.draw(ncols=2, figsize=(14, 6))

# OPEN PLAY
pitch.scatter(
    open_play["playerCoordinates.x"],
    open_play["playerCoordinates.y"],
    s=open_play["xg"] * 3000,
    color="#e74c3c",
    alpha=0.8,
    edgecolors="white",
    linewidth=0.6,
    ax=axs[0]
)
axs[0].set_title("Manchester United – Open Play Shots",
                 fontsize=13, color="white")

# SET PIECE
pitch.scatter(
    set_piece["playerCoordinates.x"],
    set_piece["playerCoordinates.y"],
    s=set_piece["xg"] * 3000,
    color="#2ecc71",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.6,
    ax=axs[1]
)
axs[1].set_title("Manchester United – Set-Piece Shots",
                 fontsize=13, color="white")

plt.suptitle(
    "MU Shot Locations\nBubble size = xG",
    fontsize=15,
    color="white"
)
plt.show()

# %%
mu = df[df["isHome"] == True].copy()

# Flip x so all shots are in attacking half (IMPORTANT)
mu["x"] = np.where(
    mu["playerCoordinates.x"] < 50,
    100 - mu["playerCoordinates.x"],
    mu["playerCoordinates.x"]
)
mu["y"] = mu["playerCoordinates.y"]

open_play = mu[~mu["situation"].isin(["corner", "free_kick"])]
set_piece = mu[mu["situation"].isin(["corner", "free_kick"])]

# ===============================
# Bubble sizes (FORCED VISIBLE)
# ===============================
open_sizes = open_play["xg"] * 8000 + 120
set_sizes  = set_piece["xg"] * 8000 + 120

# ===============================
# Half pitch
# ===============================
pitch = Pitch(
    pitch_type="opta",
    half=True,
    goal_type="box",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, axs = pitch.draw(ncols=2, figsize=(14, 6))
fig.patch.set_facecolor("#0e1117")

# ===============================
# OPEN PLAY
# ===============================
pitch.scatter(
    open_play["x"],
    open_play["y"],
    s=open_sizes,
    color="#e74c3c",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.7,
    zorder=3,
    ax=axs[0]
)

axs[0].set_title(
    "Manchester United – Open Play Shots",
    fontsize=13,
    color="white"
)

# ===============================
# SET PIECE
# ===============================
pitch.scatter(
    set_piece["x"],
    set_piece["y"],
    s=set_sizes,
    color="#2ecc71",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.7,
    zorder=3,
    ax=axs[1]
)

axs[1].set_title(
    "Manchester United – Set-Piece Shots",
    fontsize=13,
    color="white"
)

# ===============================
# Title
# ===============================
plt.suptitle(
    "Manchester United Shot Locations (Half Pitch)\nBubble size = xG",
    fontsize=15,
    color="white",
    y=1.05
)

plt.tight_layout()
plt.show()

# %%
mu = df[df["isHome"] == True]

# Kategori situasi
mu["phase"] = mu["situation"].apply(
    lambda x: "Set Piece" if x in ["corner", "free_kick"] else "Open Play"
)

# Agregasi statistik
summary = (
    mu.groupby("phase")
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        avg_xg_per_shot=("xg", "mean"),
        total_xgot=("xgot", "sum"),
        avg_xgot_per_shot=("xgot", "mean"),
    )
    .reset_index()
)

# Tambah efisiensi finishing
summary["xgot_per_xg"] = summary["total_xgot"] / summary["total_xg"]

summary
# Out:
# /var/folders/h0/lcjxkqs93vg7qg_3nsfsq85m0000gn/T/ipykernel_2508/983728900.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mu["phase"] = mu["situation"].apply(
#        phase  shots  total_xg  avg_xg_per_shot  total_xgot  avg_xgot_per_shot  \
# 0  Open Play     12  0.661307         0.055109    0.727585           0.060632
# 1  Set Piece      3  0.176185         0.058728    0.000000           0.000000
#
#    xgot_per_xg
# 0     1.100223
# 1     0.000000

# %%
mu = df[df["isHome"] == True].copy()

# Klasifikasi fase
mu["phase"] = mu["situation"].apply(
    lambda x: "Set Piece" if x in ["corner", "free_kick"] else "Open Play"
)

# Agregasi per pemain & fase
player_breakdown = (
    mu.groupby(["player.name", "phase"])
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        avg_xg=("xg", "mean"),
        total_xgot=("xgot", "sum"),
        avg_xgot=("xgot", "mean"),
    )
    .reset_index()
)

# Efisiensi finishing
player_breakdown["xgot_per_xg"] = (
    player_breakdown["total_xgot"] / player_breakdown["total_xg"]
)

# Rapikan tampilan
player_breakdown = player_breakdown.sort_values(
    ["total_xg"], ascending=False
)

player_breakdown
# Out:
#       player.name      phase  shots  total_xg    avg_xg  total_xgot  avg_xgot  \
# 1  Benjamin Šeško  Open Play      5  0.312566  0.062513    0.560014  0.112003
# 2  Benjamin Šeško  Set Piece      1  0.122577  0.122577    0.000000  0.000000
# 7   Matheus Cunha  Open Play      2  0.114702  0.057351    0.000000  0.000000
# 5  Joshua Zirkzee  Open Play      1  0.087610  0.087610    0.158051  0.158051
# 8   Patrick Dorgu  Open Play      2  0.075146  0.037573    0.000000  0.000000
# 0    Ayden Heaven  Open Play      1  0.043773  0.043773    0.000000  0.000000
# 4   Jack Fletcher  Set Piece      1  0.034750  0.034750    0.000000  0.000000
# 6   Manuel Ugarte  Open Play      1  0.027509  0.027509    0.009519  0.009519
# 3     Diogo Dalot  Set Piece      1  0.018859  0.018859    0.000000  0.000000
#
#    xgot_per_xg
# 1     1.791667
# 2     0.000000
# 7     0.000000
# 5     1.804040
# 8     0.000000
# 0     0.000000
# 4     0.000000
# 6     0.346037
# 3     0.000000

# %%
### Tactical Data

# %%
mu = df[df["isHome"] == True].copy()

mu["phase"] = np.where(
    mu["situation"].isin(["corner", "free_kick"]),
    "Set Piece",
    "Open Play"
)

# %%
mu["phase"].value_counts()
# Out:
# phase
# Open Play    12
# Set Piece     3
# Name: count, dtype: int64

# %%
def shot_zone(row):
    x, y = row["playerCoordinates.x"], row["playerCoordinates.y"]

    # Central box (cutback zone)
    if x >= 83 and 36 <= y <= 64:
        return "Central / Cutback Zone"

    # Wide box
    if x >= 83 and (y < 36 or y > 64):
        return "Wide Box"

    # Outside box
    if x < 83:
        return "Outside Box"

    return "Other"

mu["zone"] = mu.apply(shot_zone, axis=1)

# %%
def shot_zone(row):
    x = row["playerCoordinates.x"]
    y = row["playerCoordinates.y"]

    if x >= 83 and 36 <= y <= 64:
        return "Central / Cutback Zone"
    elif x >= 83:
        return "Wide Box"
    else:
        return "Outside Box"

mu["zone"] = mu.apply(shot_zone, axis=1)
mu["zone"].value_counts()
# Out:
# zone
# Outside Box    15
# Name: count, dtype: int64

# %%
players = ["Benjamin Šeško", "Patrick Dorgu", "Joshua Zirkzee"]

finish_breakdown = (
    mu[mu["player.name"].isin(players)]
    .groupby(["player.name", "bodyPart"])
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        total_xgot=("xgot", "sum"),
        avg_xg=("xg", "mean")
    )
    .reset_index()
)

# %%
sesko_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Benjamin Šeško"
]
sesko_finish
# Out:
#       player.name    bodyPart  shots  total_xg  total_xgot    avg_xg
# 0  Benjamin Šeško        head      4  0.325057    0.303023  0.081264
# 1  Benjamin Šeško  right-foot      2  0.110086    0.256991  0.055043

# %%
dorgu_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Patrick Dorgu"
]
dorgu_finish
# Out:
#      player.name   bodyPart  shots  total_xg  total_xgot    avg_xg
# 3  Patrick Dorgu  left-foot      2  0.075146         0.0  0.037573

# %%
zirkzee_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Joshua Zirkzee"
]
zirkzee_finish
# Out:
#       player.name   bodyPart  shots  total_xg  total_xgot   avg_xg
# 2  Joshua Zirkzee  left-foot      1   0.08761    0.158051  0.08761

# %% [markdown]
# ##### Šeško: High volume headers but low xGOT conversion → headers often weak or directed at the goalkeeper.
#
# ##### Dorgu: Low xG shots, mostly speculative attempts.
#
# ##### Zirkzee: More balanced finishing profile with better xGOT-to-xG alignment.

# %%
cutback_ratio = (
    mu[mu["zone"] == "Central / Cutback Zone"]["xg"].sum()
    / mu["xg"].sum()
)

cutback_ratio
# Out:
# np.float64(0.0)

# %%
summary = {
    "Total Shots": mu.shape[0],
    "Total xG": mu["xg"].sum(),
    "Open Play xG": mu[mu["phase"] == "Open Play"]["xg"].sum(),
    "Set Piece xG": mu[mu["phase"] == "Set Piece"]["xg"].sum(),
    "Cutback Zone xG": mu[mu["zone"] == "Central / Cutback Zone"]["xg"].sum()
}

pd.DataFrame(summary, index=["Manchester United"])
# Out:
#                    Total Shots  Total xG  Open Play xG  Set Piece xG  \
# Manchester United           15  0.837492      0.661307      0.176185
#
#                    Cutback Zone xG
# Manchester United              0.0
