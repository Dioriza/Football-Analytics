# %% [markdown]
# # Package Installation

# %%
pip install mplsoccer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
from mplsoccer import add_image, FontManager
from mplsoccer import Pitch

# %% [markdown]
# # Data Preparation

# %%
raw = '''{"shotmap":[{"player":{"name":"Anton Stach","firstName":"","lastName":"","slug":"anton-stach","shortName":"A. Stach","position":"M","jerseyNumber":"18","userCount":1340,"gender":"M","id":889861,"fieldTranslations":{"nameTranslation":{"ar":"\u0623\u0646\u062a\u0648\u0646 \u0633\u062a\u0627\u062e","hi":"\u090f\u0902\u091f\u094b\u0928 \u0938\u094d\u091f\u0948\u091a","bn":"\u0985\u09cd\u09af\u09be\u09a8\u09cd\u099f\u09a8 \u09b8\u09cd\u099f\u09cd\u09af\u09be\u099a"},"shortNameTranslation":{"ar":"\u0623. \u0633\u062a\u0627\u062e","hi":"\u090f. \u0938\u094d\u091f\u0948\u091a","bn":"\u098f. \u09b8\u09cd\u099f\u09cd\u09af\u09be\u099a"}}},"isHome":true,"shotType":"miss","situation":"regular","playerCoordinates":{"x":22.7,"y":41.5,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":50.6,"z":62.5},"xg":0.025846682488918,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453587,"time":90,"addedTime":4,"timeSeconds":5609,"draw":{"start":{"x":41.5,"y":22.7},"end":{"x":49.4,"y":0},"goal":{"x":49.4,"y":37.5}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":691,"periodTimeSeconds":209,"incidentType":"shot"},{"player":{"name":"Jo\u00ebl Piroe","slug":"joel-piroe","shortName":"J. Piroe","position":"F","jerseyNumber":"10","userCount":2080,"gender":"M","id":850823,"fieldTranslations":{"nameTranslation":{"ar":"\u062c\u0648\u064a\u0644 \u0628\u064a\u0631\u0648\u064a","hi":"\u091c\u094b\u090f\u0932 \u092a\u093f\u0930\u094b","bn":"\u099c\u09cb\u09af\u09bc\u09c7\u09b2 \u09aa\u09bf\u09b0\u09cb"},"shortNameTranslation":{"ar":"\u062c. \u0628\u064a\u0631\u0648\u064a","hi":"\u091c\u0947. \u092a\u093f\u0930\u094b","bn":"\u099c\u09c7. \u09aa\u09bf\u09b0\u09cb"}}},"isHome":true,"shotType":"block","situation":"corner","playerCoordinates":{"x":16.4,"y":41.8,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.2,"z":19},"blockCoordinates":{"x":8.5,"y":45.7,"z":0},"xg":0.041972599923611,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453584,"time":90,"addedTime":2,"timeSeconds":5463,"draw":{"start":{"x":41.8,"y":16.4},"block":{"x":45.7,"y":8.5},"end":{"x":49.8,"y":0},"goal":{"x":49.8,"y":81}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":837,"periodTimeSeconds":63,"incidentType":"shot"},{"player":{"name":"Jo\u00ebl Piroe","slug":"joel-piroe","shortName":"J. Piroe","position":"F","jerseyNumber":"10","userCount":2080,"gender":"M","id":850823,"fieldTranslations":{"nameTranslation":{"ar":"\u062c\u0648\u064a\u0644 \u0628\u064a\u0631\u0648\u064a","hi":"\u091c\u094b\u090f\u0932 \u092a\u093f\u0930\u094b","bn":"\u099c\u09cb\u09af\u09bc\u09c7\u09b2 \u09aa\u09bf\u09b0\u09cb"},"shortNameTranslation":{"ar":"\u062c. \u0628\u064a\u0631\u0648\u064a","hi":"\u091c\u0947. \u092a\u093f\u0930\u094b","bn":"\u099c\u09c7. \u09aa\u09bf\u09b0\u09cb"}}},"isHome":true,"shotType":"miss","situation":"fast-break","playerCoordinates":{"x":15.1,"y":66.9,"z":0},"bodyPart":"left-foot","goalMouthLocation":"close-high","goalMouthCoordinates":{"x":0,"y":50.9,"z":58.3},"xg":0.063323222100735,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453576,"time":88,"timeSeconds":5253,"draw":{"start":{"x":66.9,"y":15.1},"end":{"x":49.1,"y":0},"goal":{"x":49.1,"y":41.7}},"reversedPeriodTime":3,"reversedPeriodTimeSeconds":147,"periodTimeSeconds":2553,"incidentType":"shot"},{"player":{"name":"Matheus Cunha","slug":"matheus-cunha","shortName":"M. Cunha","position":"F","jerseyNumber":"10","userCount":62724,"gender":"M","sofascoreId":"Cunha","id":886363,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u062b\u064a\u0648\u0633 \u0643\u0648\u0646\u064a\u0627","hi":"\u092e\u0948\u0925\u093f\u092f\u0938 \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u09ae\u09cd\u09af\u09be\u09a5\u09bf\u0989\u09b8 \u0995\u09c1\u09a8\u09b9\u09be"},"shortNameTranslation":{"ar":"\u0645. \u0643\u0648\u0646\u064a\u0627","hi":"\u090f\u092e. \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u098f\u09ae. \u0995\u09c1\u09a8\u09b9\u09be"}}},"isHome":false,"shotType":"post","situation":"assisted","playerCoordinates":{"x":19.1,"y":67.5,"z":0},"bodyPart":"right-foot","goalMouthLocation":"right","goalMouthCoordinates":{"x":0,"y":44.7,"z":8.9},"xg":0.024678280577064,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453564,"time":81,"timeSeconds":4839,"draw":{"start":{"x":67.5,"y":19.1},"end":{"x":55.3,"y":0},"goal":{"x":55.3,"y":91.1}},"reversedPeriodTime":10,"reversedPeriodTimeSeconds":561,"periodTimeSeconds":2139,"incidentType":"shot"},{"player":{"name":"Benjamin \u0160e\u0161ko","slug":"benjamin-sesko","shortName":"B. \u0160e\u0161ko","position":"F","jerseyNumber":"30","userCount":71496,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"\u0628\u0646\u062c\u0627\u0645\u064a\u0646 \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0947\u0902\u091c\u093e\u092e\u093f\u0928 \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09c7\u099e\u09cd\u099c\u09be\u09ae\u09bf\u09a8 \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"},"shortNameTranslation":{"ar":"\u0628. \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0940. \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09bf. \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":9.8,"y":44.3,"z":0},"bodyPart":"right-foot","goalMouthLocation":"close-left","goalMouthCoordinates":{"x":0,"y":57.1,"z":16.7},"xg":0.26423311233521,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453561,"time":74,"timeSeconds":4426,"draw":{"start":{"x":44.3,"y":9.8},"end":{"x":42.9,"y":0},"goal":{"x":42.9,"y":83.3}},"reversedPeriodTime":17,"reversedPeriodTimeSeconds":974,"periodTimeSeconds":1726,"incidentType":"shot"},{"player":{"name":"Noah Okafor","slug":"noah-okafor","shortName":"N. Okafor","position":"F","jerseyNumber":"19","userCount":5783,"gender":"M","sofascoreId":"noah.arinze","id":865523,"fieldTranslations":{"nameTranslation":{"ar":"\u0646\u0648\u0627\u0647 \u0623\u0648\u0643\u0627\u0641\u0648\u0631","hi":"\u0928\u094b\u0906 \u0913\u0915\u093e\u092b\u094b\u0930","bn":"\u09a8\u09cb\u09af\u09bc\u09be \u0993\u0995\u09be\u09ab\u09cb\u09b0"},"shortNameTranslation":{"ar":"\u0646. \u0623\u0648\u0643\u0627\u0641\u0648\u0631","hi":"\u090f\u0928. \u0913\u0915\u093e\u092b\u094b\u0930","bn":"\u098f\u09a8. \u0993\u0995\u09be\u09ab\u09cb\u09b0"}}},"isHome":true,"shotType":"save","situation":"throw-in-set-piece","playerCoordinates":{"x":8.9,"y":48.8,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":46.3,"z":16.5},"blockCoordinates":{"x":1.2,"y":49.8,"z":0},"xg":0.12182499468327,"xgot":0.71837145090103,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453499,"time":70,"timeSeconds":4166,"draw":{"start":{"x":48.8,"y":8.9},"block":{"x":49.8,"y":1.2},"end":{"x":53.7,"y":0},"goal":{"x":53.7,"y":83.5}},"reversedPeriodTime":21,"reversedPeriodTimeSeconds":1234,"periodTimeSeconds":1466,"incidentType":"shot"},{"player":{"name":"Matheus Cunha","slug":"matheus-cunha","shortName":"M. Cunha","position":"F","jerseyNumber":"10","userCount":62724,"gender":"M","sofascoreId":"Cunha","id":886363,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u062b\u064a\u0648\u0633 \u0643\u0648\u0646\u064a\u0627","hi":"\u092e\u0948\u0925\u093f\u092f\u0938 \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u09ae\u09cd\u09af\u09be\u09a5\u09bf\u0989\u09b8 \u0995\u09c1\u09a8\u09b9\u09be"},"shortNameTranslation":{"ar":"\u0645. \u0643\u0648\u0646\u064a\u0627","hi":"\u090f\u092e. \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u098f\u09ae. \u0995\u09c1\u09a8\u09b9\u09be"}}},"isHome":false,"shotType":"goal","goalType":"regular","situation":"assisted","playerCoordinates":{"x":11.9,"y":69.6,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-left","goalMouthCoordinates":{"x":0,"y":52.1,"z":5.1},"xg":0.058396976441145,"xgot":0.19383135437965,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453490,"time":65,"timeSeconds":3870,"draw":{"start":{"x":69.6,"y":11.9},"end":{"x":47.9,"y":0},"goal":{"x":47.9,"y":94.9}},"reversedPeriodTime":26,"reversedPeriodTimeSeconds":1530,"periodTimeSeconds":1170,"incidentType":"shot"},{"player":{"name":"Brenden Aaronson","firstName":"","lastName":"","slug":"brenden-aaronson","shortName":"B. Aaronson","position":"M","jerseyNumber":"11","userCount":2315,"gender":"M","id":973431,"fieldTranslations":{"nameTranslation":{"ar":"\u0628\u0631\u064a\u0646\u062f\u0646 \u0622\u0631\u0648\u0646\u0633\u0648\u0646","hi":"\u092c\u094d\u0930\u0947\u0902\u0921\u0928 \u0906\u0930\u094b\u0928\u0938\u0928","bn":"\u09ac\u09cd\u09b0\u09c7\u09a8\u09cd\u09a1\u09c7\u09a8 \u0985\u09cd\u09af\u09be\u09b0\u09a8\u09b8\u09a8"},"shortNameTranslation":{"ar":"\u0628. \u0622\u0631\u0648\u0646\u0633\u0648\u0646","hi":"\u092c\u0940. \u0906\u0930\u094b\u0928\u0938\u0928","bn":"\u09ac\u09bf. \u0985\u09cd\u09af\u09be\u09b0\u09a8\u09b8\u09a8"}}},"isHome":true,"shotType":"goal","goalType":"regular","situation":"fast-break","playerCoordinates":{"x":10.9,"y":39.1,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":47.2,"z":1.9},"xg":0.33732596039772,"xgot":0.50470000505447,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453486,"time":62,"timeSeconds":3696,"draw":{"start":{"x":39.1,"y":10.9},"end":{"x":52.8,"y":0},"goal":{"x":52.8,"y":98.1}},"reversedPeriodTime":29,"reversedPeriodTimeSeconds":1704,"periodTimeSeconds":996,"incidentType":"shot"},{"player":{"name":"Benjamin \u0160e\u0161ko","slug":"benjamin-sesko","shortName":"B. \u0160e\u0161ko","position":"F","jerseyNumber":"30","userCount":71496,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"\u0628\u0646\u062c\u0627\u0645\u064a\u0646 \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0947\u0902\u091c\u093e\u092e\u093f\u0928 \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09c7\u099e\u09cd\u099c\u09be\u09ae\u09bf\u09a8 \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"},"shortNameTranslation":{"ar":"\u0628. \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0940. \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09bf. \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":7.3,"y":49.3,"z":0},"bodyPart":"head","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":71.6,"z":5.6},"xg":0.35471540689468,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453435,"time":54,"timeSeconds":3205,"draw":{"start":{"x":49.3,"y":7.3},"end":{"x":28.4,"y":0},"goal":{"x":28.4,"y":94.4}},"reversedPeriodTime":37,"reversedPeriodTimeSeconds":2195,"periodTimeSeconds":505,"incidentType":"shot"},{"player":{"name":"Manuel Ugarte","slug":"manuel-ugarte","shortName":"M. Ugarte","position":"M","jerseyNumber":"25","userCount":18993,"gender":"M","sofascoreId":"ugartemanu","id":846425,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u0646\u0648\u064a\u0644 \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u092e\u0948\u0928\u0941\u0905\u0932 \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u09ae\u09cd\u09af\u09be\u09a8\u09c1\u09af\u09bc\u09c7\u09b2 \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"},"shortNameTranslation":{"ar":"\u0645. \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u090f\u092e. \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u098f\u09ae. \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"}}},"isHome":false,"shotType":"miss","situation":"fast-break","playerCoordinates":{"x":17.9,"y":52.3,"z":0},"bodyPart":"left-foot","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":67.6,"z":11.1},"xg":0.088291227817535,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453429,"time":52,"timeSeconds":3092,"draw":{"start":{"x":52.3,"y":17.9},"end":{"x":32.4,"y":0},"goal":{"x":32.4,"y":88.9}},"reversedPeriodTime":39,"reversedPeriodTimeSeconds":2308,"periodTimeSeconds":392,"incidentType":"shot"},{"player":{"name":"Gabriel Gudmundsson","slug":"gabriel-gudmundsson","shortName":"G. Gudmundsson","position":"D","jerseyNumber":"3","userCount":1165,"gender":"M","id":834308,"fieldTranslations":{"nameTranslation":{"ar":"\u063a\u0627\u0628\u0631\u064a\u064a\u0644 \u063a\u0648\u062f\u0645\u0646\u062f\u0633\u0648\u0646","hi":"\u0917\u0947\u092c\u094d\u0930\u093f\u092f\u0932 \u0917\u0941\u0921\u092e\u0902\u0921\u0938\u0928","bn":"\u0997\u09cd\u09af\u09be\u09ac\u09cd\u09b0\u09bf\u09af\u09bc\u09c7\u09b2 \u0997\u09c1\u09a1\u09ae\u09c1\u09a8\u09cd\u09a1\u09b8\u09a8"},"shortNameTranslation":{"ar":"\u063a. \u063a\u0648\u062f\u0645\u0646\u062f\u0633\u0648\u0646","hi":"\u091c\u0940. \u0917\u0941\u0921\u092e\u0902\u0921\u0938\u0928","bn":"\u099c\u09bf. \u0997\u09c1\u09a1\u09ae\u09c1\u09a8\u09cd\u09a1\u09b8\u09a8"}}},"isHome":true,"shotType":"save","situation":"throw-in-set-piece","playerCoordinates":{"x":4.5,"y":70.7,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":45.7,"z":10.1},"blockCoordinates":{"x":0.59999999999999,"y":54,"z":0},"xg":0.015003898181021,"xgot":0.12153685837984,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453426,"time":51,"timeSeconds":3047,"draw":{"start":{"x":70.7,"y":4.5},"block":{"x":54,"y":0.59999999999999},"end":{"x":54.3,"y":0},"goal":{"x":54.3,"y":89.9}},"reversedPeriodTime":40,"reversedPeriodTimeSeconds":2353,"periodTimeSeconds":347,"incidentType":"shot"},{"player":{"name":"Patrick Dorgu","firstName":"","lastName":"","slug":"dorgu-patrick","shortName":"P. Dorgu","position":"M","jerseyNumber":"13","userCount":15942,"gender":"M","sofascoreId":"Odogwu","id":1397168,"fieldTranslations":{"nameTranslation":{"ar":"\u062f\u0648\u0631\u063a\u0648\u060c \u0628\u0627\u062a\u0631\u064a\u0643","hi":"\u0921\u094b\u0930\u094d\u0917\u0942, \u092a\u0948\u091f\u094d\u0930\u093f\u0915","bn":"\u09a1\u09b0\u0997\u09c1, \u09aa\u09cd\u09af\u09be\u099f\u09cd\u09b0\u09bf\u0995"},"shortNameTranslation":{"ar":"\u0628. \u062f\u0648\u0631\u063a\u0648","hi":"\u092a\u0940. \u0921\u094b\u0930\u094d\u0917\u0942","bn":"\u09aa\u09bf. \u09a1\u09b0\u0997\u09c1"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":19.8,"y":52.3,"z":0},"bodyPart":"left-foot","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":60.8,"z":6.9},"xg":0.059814531356096,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453252,"time":45,"addedTime":1,"timeSeconds":2707,"draw":{"start":{"x":52.3,"y":19.8},"end":{"x":39.2,"y":0},"goal":{"x":39.2,"y":93.1}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":2693,"periodTimeSeconds":7,"incidentType":"shot"},{"player":{"name":"Casemiro","firstName":"","lastName":"","slug":"casemiro","shortName":"Casemiro","position":"M","jerseyNumber":"18","userCount":87895,"gender":"M","sofascoreId":"Casemiro","id":122951,"fieldTranslations":{"nameTranslation":{"ar":"\u0643\u0627\u0633\u064a\u0645\u064a\u0631\u0648","hi":"\u0915\u0948\u0938\u0947\u092e\u093f\u0930\u094b","bn":"\u0995\u09cd\u09af\u09be\u09b8\u09c7\u09ae\u09bf\u09b0\u09cb"},"shortNameTranslation":{"ar":"\u0643\u0627\u0633\u064a\u0645\u064a\u0631\u0648","hi":"\u0915\u0948\u0938\u0947\u092e\u093f\u0930\u094b","bn":"\u0995\u09cd\u09af\u09be\u09b8\u09c7\u09ae\u09bf\u09b0\u09cb"}}},"isHome":false,"shotType":"block","situation":"regular","playerCoordinates":{"x":24.9,"y":50.3,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.9,"z":19},"blockCoordinates":{"x":22.4,"y":50.2,"z":0},"xg":0.021019348874688,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453248,"time":42,"timeSeconds":2499,"draw":{"start":{"x":50.3,"y":24.9},"block":{"x":50.2,"y":22.4},"end":{"x":49.1,"y":0},"goal":{"x":49.1,"y":81}},"reversedPeriodTime":4,"reversedPeriodTimeSeconds":201,"periodTimeSeconds":2499,"incidentType":"shot"},{"player":{"name":"Matheus Cunha","slug":"matheus-cunha","shortName":"M. Cunha","position":"F","jerseyNumber":"10","userCount":62724,"gender":"M","sofascoreId":"Cunha","id":886363,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u062b\u064a\u0648\u0633 \u0643\u0648\u0646\u064a\u0627","hi":"\u092e\u0948\u0925\u093f\u092f\u0938 \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u09ae\u09cd\u09af\u09be\u09a5\u09bf\u0989\u09b8 \u0995\u09c1\u09a8\u09b9\u09be"},"shortNameTranslation":{"ar":"\u0645. \u0643\u0648\u0646\u064a\u0627","hi":"\u090f\u092e. \u0915\u0941\u0928\u094d\u0939\u093e","bn":"\u098f\u09ae. \u0995\u09c1\u09a8\u09b9\u09be"}}},"isHome":false,"shotType":"miss","situation":"corner","playerCoordinates":{"x":11.8,"y":45.1,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high-right","goalMouthCoordinates":{"x":0,"y":40.2,"z":87.5},"xg":0.040447868406773,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453042,"time":41,"timeSeconds":2419,"draw":{"start":{"x":45.1,"y":11.8},"end":{"x":59.8,"y":0},"goal":{"x":59.8,"y":12.5}},"reversedPeriodTime":5,"reversedPeriodTimeSeconds":281,"periodTimeSeconds":2419,"incidentType":"shot"},{"player":{"name":"Leny Yoro","firstName":"Leny Yoro","lastName":"","slug":"leny-yoro","shortName":"L. Yoro","position":"D","jerseyNumber":"15","userCount":19788,"gender":"M","sofascoreId":"YL15","id":1153315,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u064a\u0646\u064a \u064a\u0648\u0631\u0648","hi":"\u0932\u0947\u0928\u0940 \u092f\u094b\u0930\u094b","bn":"\u09b2\u09c7\u09a8\u09bf \u0987\u09af\u09bc\u09cb\u09b0\u09cb"},"shortNameTranslation":{"ar":"\u0644. \u064a\u0648\u0631\u0648","hi":"\u090f\u0932. \u092f\u094b\u0930\u094b","bn":"\u098f\u09b2. \u0987\u09af\u09bc\u09cb\u09b0\u09cb"}}},"isHome":false,"shotType":"save","situation":"corner","playerCoordinates":{"x":3.6,"y":50.1,"z":0},"bodyPart":"head","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":50.8,"z":18.4},"blockCoordinates":{"x":0.5,"y":50.2,"z":0},"xg":0.31172779202461,"xgot":0.38136404752731,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453039,"time":40,"timeSeconds":2388,"draw":{"start":{"x":50.1,"y":3.6},"block":{"x":50.2,"y":0.5},"end":{"x":49.2,"y":0},"goal":{"x":49.2,"y":81.6}},"reversedPeriodTime":6,"reversedPeriodTimeSeconds":312,"periodTimeSeconds":2388,"incidentType":"shot"},{"player":{"name":"Casemiro","firstName":"","lastName":"","slug":"casemiro","shortName":"Casemiro","position":"M","jerseyNumber":"18","userCount":87895,"gender":"M","sofascoreId":"Casemiro","id":122951,"fieldTranslations":{"nameTranslation":{"ar":"\u0643\u0627\u0633\u064a\u0645\u064a\u0631\u0648","hi":"\u0915\u0948\u0938\u0947\u092e\u093f\u0930\u094b","bn":"\u0995\u09cd\u09af\u09be\u09b8\u09c7\u09ae\u09bf\u09b0\u09cb"},"shortNameTranslation":{"ar":"\u0643\u0627\u0633\u064a\u0645\u064a\u0631\u0648","hi":"\u0915\u0948\u0938\u0947\u092e\u093f\u0930\u094b","bn":"\u0995\u09cd\u09af\u09be\u09b8\u09c7\u09ae\u09bf\u09b0\u09cb"}}},"isHome":false,"shotType":"block","situation":"corner","playerCoordinates":{"x":9.2,"y":41.1,"z":0},"bodyPart":"head","goalMouthLocation":"low-right","goalMouthCoordinates":{"x":0,"y":48.1,"z":19},"blockCoordinates":{"x":4.2,"y":46.9,"z":0},"xg":0.027975879609585,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453041,"time":40,"timeSeconds":2386,"draw":{"start":{"x":41.1,"y":9.2},"block":{"x":46.9,"y":4.2},"end":{"x":51.9,"y":0},"goal":{"x":51.9,"y":81}},"reversedPeriodTime":6,"reversedPeriodTimeSeconds":314,"periodTimeSeconds":2386,"incidentType":"shot"},{"player":{"name":"Dominic Calvert-Lewin","slug":"dominic-calvert-lewin","shortName":"D. Calvert-Lewin","position":"F","jerseyNumber":"9","userCount":5447,"gender":"M","sofascoreId":"CalvertLewin14","id":372344,"fieldTranslations":{"nameTranslation":{"ar":"\u062f\u0648\u0645\u064a\u0646\u064a\u0643 \u0643\u0627\u0644\u0641\u064a\u0631\u062a-\u0644\u0648\u064a\u0646","hi":"\u0921\u094b\u092e\u093f\u0928\u093f\u0915 \u0915\u0948\u0932\u094d\u0935\u0930\u094d\u091f-\u0932\u0947\u0935\u093f\u0928","bn":"\u09a1\u09ae\u09bf\u09a8\u09bf\u0995 \u0995\u09be\u09b2\u09ad\u09be\u09b0\u09cd\u099f-\u09b2\u09c7\u0989\u0987\u09a8"},"shortNameTranslation":{"ar":"\u062f. \u0643\u0627\u0644\u0641\u064a\u0631\u062a-\u0644\u0648\u064a\u0646","hi":"\u0921\u0940. \u0915\u0948\u0932\u094d\u0935\u0930\u094d\u091f-\u0932\u0947\u0935\u093f\u0928","bn":"\u09a1\u09bf. \u0995\u09be\u09b2\u09ad\u09be\u09b0\u09cd\u099f-\u09b2\u09c7\u0989\u0987\u09a8"}}},"isHome":true,"shotType":"post","situation":"throw-in-set-piece","playerCoordinates":{"x":6.5,"y":58.4,"z":0},"bodyPart":"head","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":55.2,"z":16.5},"xg":0.16623303294182,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453032,"time":35,"timeSeconds":2092,"draw":{"start":{"x":58.4,"y":6.5},"end":{"x":44.8,"y":0},"goal":{"x":44.8,"y":83.5}},"reversedPeriodTime":11,"reversedPeriodTimeSeconds":608,"periodTimeSeconds":2092,"incidentType":"shot"},{"player":{"name":"Brenden Aaronson","firstName":"","lastName":"","slug":"brenden-aaronson","shortName":"B. Aaronson","position":"M","jerseyNumber":"11","userCount":2315,"gender":"M","id":973431,"fieldTranslations":{"nameTranslation":{"ar":"\u0628\u0631\u064a\u0646\u062f\u0646 \u0622\u0631\u0648\u0646\u0633\u0648\u0646","hi":"\u092c\u094d\u0930\u0947\u0902\u0921\u0928 \u0906\u0930\u094b\u0928\u0938\u0928","bn":"\u09ac\u09cd\u09b0\u09c7\u09a8\u09cd\u09a1\u09c7\u09a8 \u0985\u09cd\u09af\u09be\u09b0\u09a8\u09b8\u09a8"},"shortNameTranslation":{"ar":"\u0628. \u0622\u0631\u0648\u0646\u0633\u0648\u0646","hi":"\u092c\u0940. \u0906\u0930\u094b\u0928\u0938\u0928","bn":"\u09ac\u09bf. \u0985\u09cd\u09af\u09be\u09b0\u09a8\u09b8\u09a8"}}},"isHome":true,"shotType":"miss","situation":"regular","playerCoordinates":{"x":23.5,"y":49.9,"z":0},"bodyPart":"right-foot","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":61.8,"z":1.4},"xg":0.024594064801931,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453027,"time":32,"timeSeconds":1875,"draw":{"start":{"x":49.9,"y":23.5},"end":{"x":38.2,"y":0},"goal":{"x":38.2,"y":98.6}},"reversedPeriodTime":14,"reversedPeriodTimeSeconds":825,"periodTimeSeconds":1875,"incidentType":"shot"},{"player":{"name":"Diogo Dalot","firstName":"","lastName":"","slug":"diogo-dalot","shortName":"D. Dalot","position":"M","jerseyNumber":"2","userCount":22692,"gender":"M","sofascoreId":"DDalot","id":843200,"fieldTranslations":{"nameTranslation":{"ar":"\u062f\u064a\u0648\u063a\u0648 \u062f\u0627\u0644\u0648\u062a","hi":"\u0921\u093f\u0913\u0917\u094b \u0921\u093e\u0932\u094b\u0924","bn":"\u09a1\u09bf\u0993\u0997\u09cb \u09a1\u09be\u09b2\u099f"},"shortNameTranslation":{"ar":"\u062f. \u062f\u0627\u0644\u0648\u062a","hi":"\u0921\u0940. \u0921\u093e\u0932\u094b\u0924","bn":"\u09a1\u09bf. \u09a1\u09be\u09b2\u099f"}}},"isHome":false,"shotType":"miss","situation":"corner","playerCoordinates":{"x":12,"y":38.5,"z":0},"bodyPart":"left-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":49.4,"z":88.9},"xg":0.049064427614212,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453026,"time":31,"timeSeconds":1813,"draw":{"start":{"x":38.5,"y":12},"end":{"x":50.6,"y":0},"goal":{"x":50.6,"y":11.1}},"reversedPeriodTime":15,"reversedPeriodTimeSeconds":887,"periodTimeSeconds":1813,"incidentType":"shot"},{"player":{"name":"James Justin","firstName":"","lastName":"","slug":"james-justin","shortName":"J. Justin","position":"D","jerseyNumber":"24","userCount":1119,"gender":"M","id":827681,"fieldTranslations":{"nameTranslation":{"ar":"\u062c\u064a\u0645\u0633 \u062c\u0627\u0633\u062a\u064a\u0646","hi":"\u091c\u0947\u092e\u094d\u0938 \u091c\u0938\u094d\u091f\u093f\u0928","bn":"\u099c\u09c7\u09ae\u09b8 \u099c\u09be\u09b8\u09cd\u099f\u09bf\u09a8"},"shortNameTranslation":{"ar":"\u062c. \u062c\u0627\u0633\u062a\u064a\u0646","hi":"\u091c\u0947. \u091c\u0938\u094d\u091f\u093f\u0928","bn":"\u099c\u09c7.\u099c\u09be\u09b8\u09cd\u099f\u09bf\u09a8"}}},"isHome":true,"shotType":"miss","situation":"corner","playerCoordinates":{"x":8.4,"y":68,"z":0},"bodyPart":"head","goalMouthLocation":"left","goalMouthCoordinates":{"x":0,"y":63.5,"z":12.5},"blockCoordinates":{"x":7,"y":60.8,"z":0},"xg":0.010375767946243,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6453025,"time":25,"timeSeconds":1456,"draw":{"start":{"x":68,"y":8.4},"block":{"x":60.8,"y":7},"end":{"x":36.5,"y":0},"goal":{"x":36.5,"y":87.5}},"reversedPeriodTime":21,"reversedPeriodTimeSeconds":1244,"periodTimeSeconds":1456,"incidentType":"shot"},{"player":{"name":"Lisandro Mart\u00ednez","firstName":"","lastName":"","slug":"lisandro-martinez","shortName":"L. Mart\u00ednez","position":"D","jerseyNumber":"6","userCount":50941,"gender":"M","sofascoreId":"LichaMart\u00ednez","id":859999,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u064a\u0633\u0627\u0646\u062f\u0631\u0648 \u0645\u0627\u0631\u062a\u064a\u0646\u064a\u0632","hi":"\u0932\u093f\u0938\u093e\u0902\u0921\u094d\u0930\u094b \u092e\u093e\u0930\u094d\u091f\u093f\u0928\u0947\u091c","bn":"\u09b2\u09bf\u09b8\u09be\u09a8\u09cd\u09a6\u09cd\u09b0\u09cb \u09ae\u09be\u09b0\u09cd\u099f\u09bf\u09a8\u09c7\u099c"},"shortNameTranslation":{"ar":"\u0644. \u0645\u0627\u0631\u062a\u064a\u0646\u064a\u0632","hi":"\u090f\u0932. \u092e\u093e\u0930\u094d\u091f\u093f\u0928\u0947\u091c","bn":"\u098f\u09b2. \u09ae\u09be\u09b0\u09cd\u099f\u09bf\u09a8\u09c7\u099c"}}},"isHome":false,"shotType":"block","situation":"assisted","playerCoordinates":{"x":30.6,"y":35.1,"z":0},"bodyPart":"left-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":51.7,"z":19},"blockCoordinates":{"x":23.7,"y":38.1,"z":0},"xg":0.011679560877383,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6453023,"time":22,"timeSeconds":1273,"draw":{"start":{"x":35.1,"y":30.6},"block":{"x":38.1,"y":23.7},"end":{"x":48.3,"y":0},"goal":{"x":48.3,"y":81}},"reversedPeriodTime":24,"reversedPeriodTimeSeconds":1427,"periodTimeSeconds":1273,"incidentType":"shot"},{"player":{"name":"Manuel Ugarte","slug":"manuel-ugarte","shortName":"M. Ugarte","position":"M","jerseyNumber":"25","userCount":18993,"gender":"M","sofascoreId":"ugartemanu","id":846425,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u0646\u0648\u064a\u0644 \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u092e\u0948\u0928\u0941\u0905\u0932 \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u09ae\u09cd\u09af\u09be\u09a8\u09c1\u09af\u09bc\u09c7\u09b2 \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"},"shortNameTranslation":{"ar":"\u0645. \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u090f\u092e. \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u098f\u09ae. \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"}}},"isHome":false,"shotType":"block","situation":"regular","playerCoordinates":{"x":26.1,"y":64.1,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-left","goalMouthCoordinates":{"x":0,"y":51.9,"z":19},"blockCoordinates":{"x":13.4,"y":56.3,"z":0},"xg":0.0081603927537799,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6452956,"time":17,"timeSeconds":963,"draw":{"start":{"x":64.1,"y":26.1},"block":{"x":56.3,"y":13.4},"end":{"x":48.1,"y":0},"goal":{"x":48.1,"y":81}},"reversedPeriodTime":29,"reversedPeriodTimeSeconds":1737,"periodTimeSeconds":963,"incidentType":"shot"},{"player":{"name":"Benjamin \u0160e\u0161ko","slug":"benjamin-sesko","shortName":"B. \u0160e\u0161ko","position":"F","jerseyNumber":"30","userCount":71496,"gender":"M","sofascoreId":"benjamin_sesko","id":986397,"fieldTranslations":{"nameTranslation":{"ar":"\u0628\u0646\u062c\u0627\u0645\u064a\u0646 \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0947\u0902\u091c\u093e\u092e\u093f\u0928 \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09c7\u099e\u09cd\u099c\u09be\u09ae\u09bf\u09a8 \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"},"shortNameTranslation":{"ar":"\u0628. \u0633\u064a\u0633\u0643\u0648","hi":"\u092c\u0940. \u0938\u0947\u0938\u094d\u0915\u094b","bn":"\u09ac\u09bf. \u09b6\u09c7\u09b8\u09cd\u0995\u09cb"}}},"isHome":false,"shotType":"block","situation":"assisted","playerCoordinates":{"x":14.5,"y":57.4,"z":0},"bodyPart":"right-foot","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":48.5,"z":19},"blockCoordinates":{"x":12.3,"y":56.5,"z":0},"xg":0.11864594370127,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6452958,"time":16,"timeSeconds":951,"draw":{"start":{"x":57.4,"y":14.5},"block":{"x":56.5,"y":12.3},"end":{"x":51.5,"y":0},"goal":{"x":51.5,"y":81}},"reversedPeriodTime":30,"reversedPeriodTimeSeconds":1749,"periodTimeSeconds":951,"incidentType":"shot"},{"player":{"name":"Dominic Calvert-Lewin","slug":"dominic-calvert-lewin","shortName":"D. Calvert-Lewin","position":"F","jerseyNumber":"9","userCount":5447,"gender":"M","sofascoreId":"CalvertLewin14","id":372344,"fieldTranslations":{"nameTranslation":{"ar":"\u062f\u0648\u0645\u064a\u0646\u064a\u0643 \u0643\u0627\u0644\u0641\u064a\u0631\u062a-\u0644\u0648\u064a\u0646","hi":"\u0921\u094b\u092e\u093f\u0928\u093f\u0915 \u0915\u0948\u0932\u094d\u0935\u0930\u094d\u091f-\u0932\u0947\u0935\u093f\u0928","bn":"\u09a1\u09ae\u09bf\u09a8\u09bf\u0995 \u0995\u09be\u09b2\u09ad\u09be\u09b0\u09cd\u099f-\u09b2\u09c7\u0989\u0987\u09a8"},"shortNameTranslation":{"ar":"\u062f. \u0643\u0627\u0644\u0641\u064a\u0631\u062a-\u0644\u0648\u064a\u0646","hi":"\u0921\u0940. \u0915\u0948\u0932\u094d\u0935\u0930\u094d\u091f-\u0932\u0947\u0935\u093f\u0928","bn":"\u09a1\u09bf. \u0995\u09be\u09b2\u09ad\u09be\u09b0\u09cd\u099f-\u09b2\u09c7\u0989\u0987\u09a8"}}},"isHome":true,"shotType":"miss","situation":"fast-break","playerCoordinates":{"x":9.5,"y":39.1,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":52.8,"z":73.6},"xg":0.11453925073147,"xgot":0,"goalkeeper":{"name":"Senne Lammens","firstName":"","lastName":"","slug":"senne-lammens","shortName":"S. Lammens","position":"G","jerseyNumber":"31","userCount":25378,"gender":"M","id":964753,"fieldTranslations":{"nameTranslation":{"ar":"\u0633\u064a\u0646\u064a \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u0938\u0947\u0928\u0947 \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u09b8\u09c7\u09a8\u09c7 \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"},"shortNameTranslation":{"ar":"\u0633. \u0644\u0627\u0645\u064a\u0646\u0633","hi":"\u090f\u0938. \u0932\u093e\u092e\u0947\u0928\u094d\u0938","bn":"\u098f\u09b8. \u09b2\u09cd\u09af\u09be\u09ae\u09c7\u09a8\u09b8"}}},"id":6452897,"time":9,"timeSeconds":536,"draw":{"start":{"x":39.1,"y":9.5},"end":{"x":47.2,"y":0},"goal":{"x":47.2,"y":26.4}},"reversedPeriodTime":37,"reversedPeriodTimeSeconds":2164,"periodTimeSeconds":536,"incidentType":"shot"},{"player":{"name":"Manuel Ugarte","slug":"manuel-ugarte","shortName":"M. Ugarte","position":"M","jerseyNumber":"25","userCount":18993,"gender":"M","sofascoreId":"ugartemanu","id":846425,"fieldTranslations":{"nameTranslation":{"ar":"\u0645\u0627\u0646\u0648\u064a\u0644 \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u092e\u0948\u0928\u0941\u0905\u0932 \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u09ae\u09cd\u09af\u09be\u09a8\u09c1\u09af\u09bc\u09c7\u09b2 \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"},"shortNameTranslation":{"ar":"\u0645. \u0623\u0648\u063a\u0627\u0631\u062a\u064a","hi":"\u090f\u092e. \u0909\u0917\u093e\u0930\u094d\u091f\u0947","bn":"\u098f\u09ae. \u0989\u0997\u09be\u09b0\u09cd\u09a4\u09c7"}}},"isHome":false,"shotType":"miss","situation":"throw-in-set-piece","playerCoordinates":{"x":16.6,"y":56,"z":0},"bodyPart":"head","goalMouthLocation":"close-high","goalMouthCoordinates":{"x":0,"y":46.2,"z":52.8},"xg":0.018204063177109,"xgot":0,"goalkeeper":{"name":"Lucas Perri","firstName":"","lastName":"","slug":"lucas-perri","shortName":"L. Perri","position":"G","jerseyNumber":"1","userCount":3344,"gender":"M","id":871290,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0648\u0643\u0627\u0633 \u0628\u064a\u0631\u064a","hi":"\u0932\u0941\u0915\u093e\u0938 \u092a\u0947\u0930\u0940","bn":"\u09b2\u09c1\u0995\u09be\u09b8 \u09aa\u09c7\u09b0\u09bf"},"shortNameTranslation":{"ar":"\u0644. \u0628\u064a\u0631\u064a","hi":"\u090f\u0932. \u092a\u0947\u0930\u0940","bn":"\u098f\u09b2. \u09aa\u09c7\u09b0\u09bf"}}},"id":6452889,"time":6,"timeSeconds":324,"draw":{"start":{"x":56,"y":16.6},"end":{"x":53.8,"y":0},"goal":{"x":53.8,"y":47.2}},"reversedPeriodTime":40,"reversedPeriodTimeSeconds":2376,"periodTimeSeconds":324,"incidentType":"shot"}]}'''

# %%
data = json.loads(raw)

df = pd.json_normalize(data["shotmap"])

df = df[[
    "player.name",
    "player.position",
    "isHome",
    "shotType",
    "situation",
    "bodyPart",
    "xg",
    "xgot",
    "time",
    "timeSeconds",
    "playerCoordinates.x",
    "playerCoordinates.y"
]]

df.head()
# Out:
#       player.name player.position  isHome shotType   situation    bodyPart  \
# 0     Anton Stach               M    True     miss     regular  right-foot
# 1      Joël Piroe               F    True    block      corner   left-foot
# 2      Joël Piroe               F    True     miss  fast-break   left-foot
# 3   Matheus Cunha               F   False     post    assisted  right-foot
# 4  Benjamin Šeško               F   False     miss    assisted  right-foot
#
#          xg  xgot  time  timeSeconds  playerCoordinates.x  playerCoordinates.y
# 0  0.025847   0.0    90         5609                 22.7                 41.5
# 1  0.041973   0.0    90         5463                 16.4                 41.8
# 2  0.063323   0.0    88         5253                 15.1                 66.9
# 3  0.024678   0.0    81         4839                 19.1                 67.5
# 4  0.264233   0.0    74         4426                  9.8                 44.3

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Expected Goals (xG) Ratio

# %%
player_stats = (
    df
    .groupby("player.name")
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        total_xgot=("xgot", "sum")
    )
    .reset_index()
)

# finishing ratio quality
player_stats["xgot_ratio"] = player_stats["total_xgot"] / player_stats["total_xg"]

player_stats.sort_values("total_xg", ascending=False)
# Out:
#               player.name  shots  total_xg  total_xgot  xgot_ratio
# 1          Benjamin Šeško      3  0.737594    0.000000    0.000000
# 2        Brenden Aaronson      2  0.361920    0.504700    1.394507
# 9               Leny Yoro      1  0.311728    0.381364    1.223388
# 5   Dominic Calvert-Lewin      2  0.280772    0.000000    0.000000
# 12          Matheus Cunha      3  0.123523    0.193831    1.569191
# 13            Noah Okafor      1  0.121825    0.718371    5.896749
# 11          Manuel Ugarte      3  0.114656    0.000000    0.000000
# 8              Joël Piroe      2  0.105296    0.000000    0.000000
# 14          Patrick Dorgu      1  0.059815    0.000000    0.000000
# 4             Diogo Dalot      1  0.049064    0.000000    0.000000
# 3                Casemiro      2  0.048995    0.000000    0.000000
# 0             Anton Stach      1  0.025847    0.000000    0.000000
# 6     Gabriel Gudmundsson      1  0.015004    0.121537    8.100352
# ...

# %%
# 2 shot minimum filter
player_stats = player_stats[player_stats["shots"] >= 2]
MIN_XG = 0.2
MIN_SHOTS = 2

# %%
# Most Dangerous Players
most_dangerous = (
    player_stats
    .query("total_xg >= @MIN_XG and shots >= @MIN_SHOTS")
    .sort_values("xgot_ratio", ascending=False)
    .head(3)
)


# Most Wasteful Players
most_wasteful = (
    player_stats
    .query("total_xg >= @MIN_XG and shots >= @MIN_SHOTS")
    .sort_values("xgot_ratio", ascending=True)
    .head(3)
)

# %%
most_dangerous
# Out:
#              player.name  shots  total_xg  total_xgot  xgot_ratio
# 2       Brenden Aaronson      2  0.361920      0.5047    1.394507
# 1         Benjamin Šeško      3  0.737594      0.0000    0.000000
# 5  Dominic Calvert-Lewin      2  0.280772      0.0000    0.000000

# %%
most_wasteful
# Out:
#              player.name  shots  total_xg  total_xgot  xgot_ratio
# 1         Benjamin Šeško      3  0.737594      0.0000    0.000000
# 5  Dominic Calvert-Lewin      2  0.280772      0.0000    0.000000
# 2       Brenden Aaronson      2  0.361920      0.5047    1.394507

# %%
plt.style.use("dark_background")

fig, ax = plt.subplots(figsize=(10, 7))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

# ===============================
# Base color logic
# ===============================
colors = np.where(
    player_stats["xgot_ratio"] > 1.2, "#2ecc71",
    np.where(player_stats["xgot_ratio"] < 0.6, "#e74c3c", "#95a5a6")
)

# ===============================
# Override: (goal scorer)
# ===============================
is_krejci = player_stats["player.name"] == "Ladislav Krejčí"
colors[is_krejci] = "#f1c40f"  # gold

# ===============================
# Scatter
# ===============================
ax.scatter(
    player_stats["total_xg"],
    player_stats["total_xgot"],
    s=player_stats["shots"] * 220,
    c=colors,
    alpha=0.9,
    edgecolor="white",
    linewidth=np.where(is_krejci, 1.8, 0.7)  # highlight Krejčí
)

# ===============================
# Reference line
# ===============================
max_val = max(
    player_stats["total_xg"].max(),
    player_stats["total_xgot"].max()
)

ax.plot(
    [0, max_val],
    [0, max_val],
    linestyle="--",
    color="#f1c40f",
    linewidth=1,
    alpha=0.8
)

# ===============================
# Annotations (extremes + Krejčí)
# ===============================
for _, row in player_stats.iterrows():
    if (
        row["xgot_ratio"] < 0.6
        or row["xgot_ratio"] > 1.2
        or row["player.name"] == "Ladislav Krejčí"
    ):
        ax.annotate(
            row["player.name"],
            (row["total_xg"], row["total_xgot"]),
            xytext=(6, 6),
            textcoords="offset points",
            fontsize=9,
            color="white"
        )

# ===============================
# Quadrant Labels
# ===============================
ax.text(
    max_val * 0.75, max_val * 0.9,
    "🔥 DEADLY FINISHER\nHigh xG | High xGOT",
    fontsize=10, color="#2ecc71", ha="center", va="center"
)

ax.text(
    max_val * 0.75, max_val * 0.25,
    "❌ WASTEFUL\nHigh xG | Low xGOT",
    fontsize=10, color="#e74c3c", ha="center", va="center"
)

ax.text(
    max_val * 0.25, max_val * 0.9,
    "🎯 CLINICAL\nLow xG | High xGOT",
    fontsize=10, color="#f1c40f", ha="center", va="center"
)

ax.text(
    max_val * 0.08, max_val * 0.08,
    "⚪ LOW IMPACT\nLow xG | Low xGOT",
    fontsize=10,
    color="#ecf0f1",
    ha="left", va="bottom",
    bbox=dict(boxstyle="round,pad=0.3", fc="#000000", ec="none", alpha=0.55)
)

# ===============================
# Legend (manual, clean)
# ===============================
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Dangerous finisher',
           markerfacecolor='#2ecc71', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Wasteful',
           markerfacecolor='#e74c3c', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Neutral',
           markerfacecolor='#95a5a6', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Goal scorer (Krejčí)',
           markerfacecolor='#f1c40f', markersize=10),
    Line2D([0], [0], linestyle='--', color='#f1c40f', label='xG = xGOT')
]

ax.legend(
    handles=legend_elements,
    loc="upper left",
    frameon=False,
    fontsize=9
)

# ===============================
# Labels & title
# ===============================
ax.set_xlabel("Total xG", fontsize=11, color="white")
ax.set_ylabel("Total xGOT", fontsize=11, color="white")

ax.set_title(
    "Dangerous vs Wasteful Players",
    fontsize=15,
    color="white",
    pad=14
)

# ===============================
# Grid & spines
# ===============================
ax.grid(color="white", alpha=0.08)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#666666")
ax.spines["bottom"].set_color("#666666")

plt.tight_layout()
plt.show()

# %%
# Top 6 based on xGOT
top6_xgot = (
    player_stats
    .sort_values("total_xgot", ascending=False)
    .head(6)
    .reset_index(drop=True)
)

top6_xgot
# Out:
#              player.name  shots  total_xg  total_xgot  xgot_ratio
# 0       Brenden Aaronson      2  0.361920    0.504700    1.394507
# 1          Matheus Cunha      3  0.123523    0.193831    1.569191
# 2         Benjamin Šeško      3  0.737594    0.000000    0.000000
# 3               Casemiro      2  0.048995    0.000000    0.000000
# 4  Dominic Calvert-Lewin      2  0.280772    0.000000    0.000000
# 5             Joël Piroe      2  0.105296    0.000000    0.000000

# %%
plt.style.use("dark_background")

# Ambil Top 6 xGOT
top6_xgot = (
    player_stats
    .sort_values("total_xgot", ascending=False)
    .head(6)
    .reset_index(drop=True)
)

fig, ax = plt.subplots(figsize=(9, 6))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

# Warna: emas untuk Krejčí, abu-abu untuk lainnya
colors = [
    "#f1c40f" if name == "Ladislav Krejčí" else "#95a5a6"
    for name in top6_xgot["player.name"]
]

# Bar chart
bars = ax.barh(
    top6_xgot["player.name"],
    top6_xgot["total_xgot"],
    color=colors,
    edgecolor="white",
    alpha=0.9
)

# Value labels
for bar in bars:
    width = bar.get_width()
    ax.text(
        width + 0.02,
        bar.get_y() + bar.get_height() / 2,
        f"{width:.2f}",
        va="center",
        fontsize=10,
        color="white"
    )

# Invert y-axis (ranking)
ax.invert_yaxis()

# Labels & title
ax.set_xlabel("Total xGOT", fontsize=11)
ax.set_ylabel("")
ax.set_title(
    "Top 6 Players by Expected Goals on Target (xGOT)",
    fontsize=14,
    pad=12
)

# Grid & spines
ax.grid(axis="x", alpha=0.15)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#666666")
ax.spines["bottom"].set_color("#666666")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Shot Map

# %%
plt.scatter(
    df["playerCoordinates.y"],
    df["playerCoordinates.x"],
    c=df["xg"],
    cmap="Reds",
    s=df["xg"]*1000,
    alpha=0.7
)
plt.colorbar(label="xG")
plt.xlabel("Width")
plt.ylabel("Length")
plt.title("Shot Map based on  xG. Leeds vs United")
plt.show()

# %%
from mplsoccer import Pitch
import matplotlib.pyplot as plt

pitch = Pitch(
    pitch_type="opta",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, ax = pitch.draw(figsize=(10, 7))

# 👉 Batasi ke setengah lapangan kiri
ax.set_xlim(0, 50)

sc = pitch.scatter(
    df["playerCoordinates.x"],
    df["playerCoordinates.y"],
    s=df["xg"] * 3000,
    c=df["xgot"],
    cmap="viridis",
    edgecolors="white",
    linewidth=0.6,
    alpha=0.85,
    ax=ax
)

cbar = plt.colorbar(sc, ax=ax)
cbar.set_label("xGOT")

ax.set_title(
    "Shot Map \nBubble size = xG | Color = xGOT\nLeeds vs Manchester United",
    color="white",
    fontsize=14
)

plt.show()

# %%
# Filter shots Manchester United (away)
df_manutd = df[df['isHome'] == False]

# Buat pitch
pitch = Pitch(
    pitch_type="opta",
    pitch_color="#0e1117",  # background gelap
    line_color="#cfcfcf"
)

fig, ax = pitch.draw(figsize=(10, 7))

# Batasi ke setengah lapangan kiri (arah goal Leeds)
ax.set_xlim(0, 50)

# Tandai gol dengan warna emas
colors = df_manutd['shotType'].apply(lambda x: 'gold' if x == 'goal' else '#1f77b4')  # biru untuk non-goal

sc = pitch.scatter(
    df_manutd["playerCoordinates.x"],
    df_manutd["playerCoordinates.y"],
    s=df_manutd["xg"] * 3000,
    c=colors,
    edgecolors="white",
    linewidth=0.6,
    alpha=0.85,
    ax=ax
)

ax.set_title(
    "Manchester United Shots\nBubble size = xG | Gold = Goal",
    color="white",
    fontsize=14
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor("#0e1117")
ax.set_facecolor("#0e1117")

ax.scatter(
    df["xg"],
    df["xgot"],
    alpha=0.75,
    edgecolor="white"
)

max_val = max(df["xg"].max(), df["xgot"].max())
ax.plot([0, max_val], [0, max_val], "--", color="#f1c40f")

ax.set_xlabel("xG")
ax.set_ylabel("xGOT")
ax.set_title("Shot Quality vs Placement", color="white")

plt.show()

# %% [markdown]
# ### Open Play vs Set-piece Chances

# %%
# Filter MU shots
mu = df[df["isHome"] == False]

open_play = mu[~mu["situation"].isin(["corner", "free_kick"])]
set_piece = mu[mu["situation"].isin(["corner", "free_kick"])]

pitch = Pitch(
    pitch_type="opta",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, axs = pitch.draw(ncols=2, figsize=(14, 6))

# OPEN PLAY
pitch.scatter(
    open_play["playerCoordinates.x"],
    open_play["playerCoordinates.y"],
    s=open_play["xg"] * 3000,
    color="#e74c3c",
    alpha=0.8,
    edgecolors="white",
    linewidth=0.6,
    ax=axs[0]
)
axs[0].set_title("Manchester United – Open Play Shots",
                 fontsize=13, color="white")

# SET PIECE
pitch.scatter(
    set_piece["playerCoordinates.x"],
    set_piece["playerCoordinates.y"],
    s=set_piece["xg"] * 3000,
    color="#2ecc71",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.6,
    ax=axs[1]
)
axs[1].set_title("Manchester United – Set-Piece Shots",
                 fontsize=13, color="white")

plt.suptitle(
    "MU Shot Locations\nBubble size = xG",
    fontsize=15,
    color="white"
)
plt.show()

# %%
mu = df[df["isHome"] == False].copy()

# Flip x so all shots are in attacking half (IMPORTANT)
mu["x"] = np.where(
    mu["playerCoordinates.x"] < 50,
    100 - mu["playerCoordinates.x"],
    mu["playerCoordinates.x"]
)
mu["y"] = mu["playerCoordinates.y"]

open_play = mu[~mu["situation"].isin(["corner", "free_kick"])]
set_piece = mu[mu["situation"].isin(["corner", "free_kick"])]

# ===============================
# Bubble sizes (FORCED VISIBLE)
# ===============================
open_sizes = open_play["xg"] * 8000 + 120
set_sizes  = set_piece["xg"] * 8000 + 120

# ===============================
# Half pitch
# ===============================
pitch = Pitch(
    pitch_type="opta",
    half=True,
    goal_type="box",
    pitch_color="#0e1117",
    line_color="#cfcfcf"
)

fig, axs = pitch.draw(ncols=2, figsize=(14, 6))
fig.patch.set_facecolor("#0e1117")

# ===============================
# OPEN PLAY
# ===============================
pitch.scatter(
    open_play["x"],
    open_play["y"],
    s=open_sizes,
    color="#e74c3c",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.7,
    zorder=3,
    ax=axs[0]
)

axs[0].set_title(
    "Manchester United – Open Play Shots",
    fontsize=13,
    color="white"
)

# ===============================
# SET PIECE
# ===============================
pitch.scatter(
    set_piece["x"],
    set_piece["y"],
    s=set_sizes,
    color="#2ecc71",
    alpha=0.85,
    edgecolors="white",
    linewidth=0.7,
    zorder=3,
    ax=axs[1]
)

axs[1].set_title(
    "Manchester United – Set-Piece Shots",
    fontsize=13,
    color="white"
)

# ===============================
# Title
# ===============================
plt.suptitle(
    "Manchester United Shot Locations\nBubble size = xG",
    fontsize=15,
    color="white",
    y=1.05
)

plt.tight_layout()
plt.show()

# %%
mu = df[df["isHome"] == False]

# Kategori situasi
mu["phase"] = mu["situation"].apply(
    lambda x: "Set Piece" if x in ["corner", "free_kick"] else "Open Play"
)

# Agregasi statistik
summary = (
    mu.groupby("phase")
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        avg_xg_per_shot=("xg", "mean"),
        total_xgot=("xgot", "sum"),
        avg_xgot_per_shot=("xgot", "mean"),
    )
    .reset_index()
)

# Tambah efisiensi finishing
summary["xgot_per_xg"] = summary["total_xgot"] / summary["total_xg"]

summary
# Out:
# /var/folders/h0/lcjxkqs93vg7qg_3nsfsq85m0000gn/T/ipykernel_3148/1381415280.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mu["phase"] = mu["situation"].apply(
#        phase  shots  total_xg  avg_xg_per_shot  total_xgot  avg_xgot_per_shot  \
# 0  Open Play     11  1.027839         0.093440    0.193831           0.017621
# 1  Set Piece      4  0.429216         0.107304    0.381364           0.095341
#
#    xgot_per_xg
# 0     0.188581
# 1     0.888513

# %%
mu = df[df["isHome"] == False].copy()

# Klasifikasi fase
mu["phase"] = mu["situation"].apply(
    lambda x: "Set Piece" if x in ["corner", "free_kick"] else "Open Play"
)

# Agregasi per pemain & fase
player_breakdown = (
    mu.groupby(["player.name", "phase"])
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        avg_xg=("xg", "mean"),
        total_xgot=("xgot", "sum"),
        avg_xgot=("xgot", "mean"),
    )
    .reset_index()
)

# Efisiensi finishing
player_breakdown["xgot_per_xg"] = (
    player_breakdown["total_xgot"] / player_breakdown["total_xg"]
)

# Rapikan tampilan
player_breakdown = player_breakdown.sort_values(
    ["total_xg"], ascending=False
)

player_breakdown
# Out:
#          player.name      phase  shots  total_xg    avg_xg  total_xgot  \
# 0     Benjamin Šeško  Open Play      3  0.737594  0.245865    0.000000
# 4          Leny Yoro  Set Piece      1  0.311728  0.311728    0.381364
# 6      Manuel Ugarte  Open Play      3  0.114656  0.038219    0.000000
# 7      Matheus Cunha  Open Play      2  0.083075  0.041538    0.193831
# 9      Patrick Dorgu  Open Play      1  0.059815  0.059815    0.000000
# 3        Diogo Dalot  Set Piece      1  0.049064  0.049064    0.000000
# 8      Matheus Cunha  Set Piece      1  0.040448  0.040448    0.000000
# 2           Casemiro  Set Piece      1  0.027976  0.027976    0.000000
# 1           Casemiro  Open Play      1  0.021019  0.021019    0.000000
# 5  Lisandro Martínez  Open Play      1  0.011680  0.011680    0.000000
#
#    avg_xgot  xgot_per_xg
# 0  0.000000     0.000000
# 4  0.381364     1.223388
# 6  0.000000     0.000000
# 7  0.096916     2.333202
# 9  0.000000     0.000000
# 3  0.000000     0.000000
# ...

# %% [markdown]
# ### Tactical Data

# %%
mu = df[df["isHome"] == False].copy()

mu["phase"] = np.where(
    mu["situation"].isin(["corner", "free_kick"]),
    "Set Piece",
    "Open Play"
)

# %%
mu["phase"].value_counts()
# Out:
# phase
# Open Play    11
# Set Piece     4
# Name: count, dtype: int64

# %%
def shot_zone(row):
    x, y = row["playerCoordinates.x"], row["playerCoordinates.y"]

    # Central box (cutback zone)
    if x >= 83 and 36 <= y <= 64:
        return "Central / Cutback Zone"

    # Wide box
    if x >= 83 and (y < 36 or y > 64):
        return "Wide Box"

    # Outside box
    if x < 83:
        return "Outside Box"

    return "Other"

mu["zone"] = mu.apply(shot_zone, axis=1)

# %%
def shot_zone(row):
    x = row["playerCoordinates.x"]
    y = row["playerCoordinates.y"]

    if x >= 83 and 36 <= y <= 64:
        return "Central / Cutback Zone"
    elif x >= 83:
        return "Wide Box"
    else:
        return "Outside Box"

mu["zone"] = mu.apply(shot_zone, axis=1)
mu["zone"].value_counts()
# Out:
# zone
# Outside Box    15
# Name: count, dtype: int64

# %%
players = ["Benjamin Šeško", "Patrick Dorgu", "Matheus Cunha"]

finish_breakdown = (
    mu[mu["player.name"].isin(players)]
    .groupby(["player.name", "bodyPart"])
    .agg(
        shots=("xg", "count"),
        total_xg=("xg", "sum"),
        total_xgot=("xgot", "sum"),
        avg_xg=("xg", "mean")
    )
    .reset_index()
)

# %%
sesko_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Benjamin Šeško"
]
sesko_finish
# Out:
#       player.name    bodyPart  shots  total_xg  total_xgot    avg_xg
# 0  Benjamin Šeško        head      1  0.354715         0.0  0.354715
# 1  Benjamin Šeško  right-foot      2  0.382879         0.0  0.191440

# %%
dorgu_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Patrick Dorgu"
]
dorgu_finish
# Out:
#      player.name   bodyPart  shots  total_xg  total_xgot    avg_xg
# 3  Patrick Dorgu  left-foot      1  0.059815         0.0  0.059815

# %%
cunha_finish = finish_breakdown[
    finish_breakdown["player.name"] == "Matheus Cunha"
]
cunha_finish
# Out:
#      player.name    bodyPart  shots  total_xg  total_xgot    avg_xg
# 2  Matheus Cunha  right-foot      3  0.123523    0.193831  0.041174

# %%
cutback_ratio = (
    mu[mu["zone"] == "Central / Cutback Zone"]["xg"].sum()
    / mu["xg"].sum()
)

cutback_ratio
# Out:
# np.float64(0.0)

# %%
summary = {
    "Total Shots": mu.shape[0],
    "Total xG": mu["xg"].sum(),
    "Open Play xG": mu[mu["phase"] == "Open Play"]["xg"].sum(),
    "Set Piece xG": mu[mu["phase"] == "Set Piece"]["xg"].sum(),
    "Cutback Zone xG": mu[mu["zone"] == "Central / Cutback Zone"]["xg"].sum()
}

pd.DataFrame(summary, index=["Manchester United"])
# Out:
#                    Total Shots  Total xG  Open Play xG  Set Piece xG  \
# Manchester United           15  1.457055      1.027839      0.429216
#
#                    Cutback Zone xG
# Manchester United              0.0

# %% [markdown]
# ## Defend Analysis

# %% [markdown]
# ### Senne Lammens

# %%
raw_data = json.loads(raw)
shots = raw_data["shotmap"]
df = pd.json_normalize(shots)

df_shots = df[[
    "player.name",
    "isHome",
    "shotType",
    "situation",
    "bodyPart",
    "xg",
    "xgot",
    "goalkeeper.name",
    "playerCoordinates.x",
    "playerCoordinates.y",
    "goalMouthLocation"
]]

df_shots.rename(columns={
    "player.name": "player",
    "goalkeeper.name": "goalkeeper",
    "playerCoordinates.x": "x",
    "playerCoordinates.y": "y"
}, inplace=True)

df_shots.head()
# Out:
# /var/folders/h0/lcjxkqs93vg7qg_3nsfsq85m0000gn/T/ipykernel_3148/2141685851.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots.rename(columns={
#            player  isHome shotType   situation    bodyPart        xg  xgot  \
# 0     Anton Stach    True     miss     regular  right-foot  0.025847   0.0
# 1      Joël Piroe    True    block      corner   left-foot  0.041973   0.0
# 2      Joël Piroe    True     miss  fast-break   left-foot  0.063323   0.0
# 3   Matheus Cunha   False     post    assisted  right-foot  0.024678   0.0
# 4  Benjamin Šeško   False     miss    assisted  right-foot  0.264233   0.0
#
#       goalkeeper     x     y goalMouthLocation
# 0  Senne Lammens  22.7  41.5              high
# 1  Senne Lammens  16.4  41.8        low-centre
# ...

# %%
keeper = "Senne Lammens"

keeper_df = df_shots[
    (df_shots["goalkeeper"] == keeper) &
    (df_shots["shotType"] == "save")
]

keeper_summary = pd.DataFrame({
    "saves": [len(keeper_df)],
    "faced_xg": [keeper_df["xg"].sum()],
    "faced_xgot": [keeper_df["xgot"].sum()],
    "avg_xgot_per_save": [keeper_df["xgot"].mean()]
})

keeper_summary
# Out:
#    saves  faced_xg  faced_xgot  avg_xgot_per_save
# 0      2  0.136829    0.839908           0.419954

# %%
import pandas as pd

# Data awal
data = {
    "isHome": [False, True],
    "shots": [15, 10],
    "goals": [1, 1],
    "total_xg": [1.457055, 0.921039],
    "total_xgot": [0.575195, 1.344608],
    "shots_on_target": [2, 3]
}

df_summary = pd.DataFrame(data)

# Tambahkan nama kiper berdasarkan isHome
df_summary["goalkeeper"] = df_summary["isHome"].map({True: "Lucas Perri", False: "Senne Lammens"})

# Tambahkan kolom xGOT minus goals
df_summary["xgot_minus_goals"] = df_summary["total_xgot"] - df_summary["goals"]

# Tampilkan DataFrame akhir
df_summary = df_summary[["goalkeeper", "shots", "goals", "total_xg", "total_xgot", "shots_on_target", "xgot_minus_goals"]]
df_summary
# Out:
#       goalkeeper  shots  goals  total_xg  total_xgot  shots_on_target  \
# 0  Senne Lammens     15      1  1.457055    0.575195                2
# 1    Lucas Perri     10      1  0.921039    1.344608                3
#
#    xgot_minus_goals
# 0         -0.424805
# 1          0.344608

# %% [markdown]
# ## Defender

# %%
zone_defender_df = pd.DataFrame({
    "Zone": [
        "Left CB Zone",
        "Central Zone",
        "Right CB Zone"
    ],
    "Area Description": [
        "Left half-space inside penalty box",
        "Central box (6-yard box & penalty spot)",
        "Right half-space inside penalty box"
    ],
    "Primary Defender": [
        "Lisandro Martínez",
        "Leny Yoro",
        "Ayden Heaven"
    ]
})

zone_defender_df
# Out:
#             Zone                         Area Description   Primary Defender
# 0   Left CB Zone       Left half-space inside penalty box  Lisandro Martínez
# 1   Central Zone  Central box (6-yard box & penalty spot)          Leny Yoro
# 2  Right CB Zone      Right half-space inside penalty box       Ayden Heaven

# %%
defensive_metrics = pd.DataFrame({
    "metric": [
        "shots_conceded",
        "goals_conceded",
        "total_xg",
        "avg_xg",
        "fast_break_shots",
        "set_piece_shots",
        "xgot_minus_goals"
    ],
    "definition": [
        "Total number of opponent shots conceded",
        "Total goals conceded from those shots",
        "Sum of expected goals conceded",
        "Average xG per shot conceded",
        "Shots conceded from transition situations",
        "Shots conceded from set-piece situations",
        "xGOT conceded minus actual goals conceded"
    ]
})

defensive_metrics
# Out:
#              metric                                 definition
# 0    shots_conceded    Total number of opponent shots conceded
# 1    goals_conceded      Total goals conceded from those shots
# 2          total_xg             Sum of expected goals conceded
# 3            avg_xg               Average xG per shot conceded
# 4  fast_break_shots  Shots conceded from transition situations
# 5   set_piece_shots   Shots conceded from set-piece situations
# 6  xgot_minus_goals  xGOT conceded minus actual goals conceded

# %%
import pandas as pd
import numpy as np

# =========================
# LOAD & NORMALIZE DATA
# =========================
df = pd.json_normalize(raw_data["shotmap"], sep="_")

# only shots conceded by Manchester United
conceded = df[df["isHome"] == False].copy()

# =========================
# ZONE DEFINITION
# =========================
def zone(row):
    x, y = row["playerCoordinates_x"], row["playerCoordinates_y"]
    if x <= 14 and 36 <= y <= 64:
        return "Central Zone"
    elif y < 36:
        return "Left CB Zone"
    elif y > 64:
        return "Right CB Zone"
    return "Other"

conceded["zone"] = conceded.apply(zone, axis=1)

# =========================
# CLEAN & ORDER ZONES
# =========================
zone_order = [
    "Left CB Zone",
    "Central Zone",
    "Right CB Zone",
    "Other"
]

conceded["zone"] = conceded["zone"].astype(str).str.strip()
conceded["zone"] = pd.Categorical(
    conceded["zone"],
    categories=zone_order,
    ordered=True
)

# =========================
# GOAL FLAG
# =========================
conceded["is_goal"] = conceded["shotType"] == "goal"

# =========================
# AGGREGATION
# =========================
summary = conceded.groupby("zone", dropna=False).agg(
    shots_conceded=("shotType", "count"),
    goals_conceded=("is_goal", "sum"),
    total_xg=("xg", "sum"),
    avg_xg=("xg", "mean"),
    fast_break_shots=("situation", lambda x: (x == "fast-break").sum()),
    set_piece_shots=("situation", lambda x: x.isin([
        "corner", "free-kick", "throw-in-set-piece"
    ]).sum())
).reset_index()

# ensure correct order
summary = summary.sort_values("zone").reset_index(drop=True)

summary
# Out:
# /var/folders/h0/lcjxkqs93vg7qg_3nsfsq85m0000gn/T/ipykernel_3148/3389209838.py:52: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = conceded.groupby("zone", dropna=False).agg(
#             zone  shots_conceded  goals_conceded  total_xg    avg_xg  \
# 0   Left CB Zone               1               0  0.011680  0.011680
# 1   Central Zone               6               0  1.048164  0.174694
# 2  Right CB Zone               3               1  0.091236  0.030412
# 3          Other               5               0  0.305975  0.061195
#
#    fast_break_shots  set_piece_shots
# 0                 0                0
# 1                 0                4
# 2                 0                0
# 3                 1                1

# %%
from matplotlib.patches import Patch

fig, ax = plt.subplots(figsize=(8, 4))

# conditional colors
colors = [
    "red" if g > 0 else "grey"
    for g in danger_df["goals_conceded"]
]

ax.bar(
    danger_df["zone"],
    danger_df["danger_score"],
    color=colors
)

ax.set_title("Defensive Danger Man Utd Ranking by Zone (Total xG)")
ax.set_ylabel("Total xG Conceded")
ax.set_xlabel("Zone")

# legend
legend_elements = [
    Patch(facecolor='red', label='Zone with Goals Conceded'),
    Patch(facecolor='grey', label='Zone without Goals')
]
ax.legend(handles=legend_elements, frameon=False)

plt.tight_layout()
plt.show()

# %%
from scipy.ndimage import gaussian_filter

attack = df[df["isHome"] == True].copy()

attack = attack.dropna(subset=[
    "playerCoordinates_x",
    "playerCoordinates_y",
    "xg"
])

pitch = Pitch(
    pitch_type='statsbomb',
    line_zorder=2,
    pitch_color='#22312b',
    line_color='#efefef'
)

fig, ax = pitch.draw(figsize=(6.6, 4.125))
fig.set_facecolor('#22312b')

bin_statistic = pitch.bin_statistic(
    attack["playerCoordinates_x"],
    attack["playerCoordinates_y"],
    statistic='sum',
    values=attack["xg"],
    bins=(25, 25)
)

bin_statistic["statistic"] = gaussian_filter(
    bin_statistic["statistic"],
    sigma=1
)

pcm = pitch.heatmap(
    bin_statistic,
    ax=ax,
    cmap='hot',
    edgecolors='#22312b'
)

cbar = fig.colorbar(pcm, ax=ax, shrink=0.6)
cbar.outline.set_edgecolor('#efefef')
cbar.ax.yaxis.set_tick_params(color='#efefef')
plt.setp(
    plt.getp(cbar.ax.axes, 'yticklabels'),
    color='#efefef'
)

ax.set_title(
    "Manchester United – Defensive Danger Heatmap (xG-weighted)\n"
    "Left: Martínez | Centre: Yoro | Right: Heaven",
    color='#efefef',
    fontsize=12
)


plt.show()

# %% [markdown]
# ## Attacker

# %%
# Parsing JSON
data = json.loads(raw)
shots = data['shotmap']

# Fokus Man Utd sebagai away team
away_shots = [s for s in shots if s['isHome'] == False]

# %%
# Extract key information
effectiveness_list = []

for s in away_shots:
    situation = s['situation']      # shot situation
    xg = s['xg']                    # expected goals
    goal = 1 if s.get('goalType') else 0  # check if goal
    effectiveness_list.append({"Situation": situation, "xG": xg, "Goal": goal})

# Create DataFrame
df_effectiveness = pd.DataFrame(effectiveness_list)

# Summarize by situation
df_effectiveness_summary = df_effectiveness.groupby("Situation").agg(
    Shots_Count = ("xG", "count"),
    Total_xG = ("xG", "sum"),
    Goals = ("Goal", "sum")
).reset_index()

# Add conversion rate
df_effectiveness_summary["Conversion_Rate"] = (
    df_effectiveness_summary["Goals"] / df_effectiveness_summary["Shots_Count"] * 100
).round(2).astype(str) + "%"

print("=== Shot Effectiveness ===")
df_effectiveness_summary
# Out:
# === Shot Effectiveness ===
#             Situation  Shots_Count  Total_xG  Goals Conversion_Rate
# 0            assisted            7  0.892164      1          14.29%
# 1              corner            4  0.429216      0            0.0%
# 2          fast-break            1  0.088291      0            0.0%
# 3             regular            2  0.029180      0            0.0%
# 4  throw-in-set-piece            1  0.018204      0            0.0%

# %%
 # Define area based on y-coordinate (field length axis)
def categorize_area(y):
    if 40 <= y <= 60:
        return "Center of the Penalty Box"
    elif y < 40:
        return "Left Side of the Penalty Box"
    else:
        return "Right Side of the Penalty Box"

location_list = []

for s in away_shots:
    y = s['playerCoordinates']['y']
    area = categorize_area(y)
    goal = 1 if s.get('goalType') else 0
    xg = s['xg']
    location_list.append({"Area": area, "xG": xg, "Goal": goal})

df_location = pd.DataFrame(location_list)

# Summary
df_location_summary = df_location.groupby("Area").agg(
    Shots_Count = ("xG", "count"),
    Total_xG = ("xG", "sum"),
    Goals = ("Goal", "sum")
).reset_index()

print("\n=== Shot Location ===")
df_location_summary
# Out:
# === Shot Location ===
#                             Area  Shots_Count  Total_xG  Goals
# 0      Center of the Penalty Box           10  1.305075      0
# 1   Left Side of the Penalty Box            2  0.060744      0
# 2  Right Side of the Penalty Box            3  0.091236      1

# %%
# Extract by situation
situation_list = []

for s in away_shots:
    situation = s['situation']
    goal = 1 if s.get('goalType') else 0
    xg = s['xg']
    situation_list.append({"Situation": situation, "xG": xg, "Goal": goal})

df_situation = pd.DataFrame(situation_list)

# Summary
df_situation_summary = df_situation.groupby("Situation").agg(
    Shots_Count = ("xG", "count"),
    Total_xG = ("xG", "sum"),
    Goals = ("Goal", "sum")
).reset_index()

print("\n=== Attack Situation ===")
df_situation_summary
# Out:
# === Attack Situation ===
#             Situation  Shots_Count  Total_xG  Goals
# 0            assisted            7  0.892164      1
# 1              corner            4  0.429216      0
# 2          fast-break            1  0.088291      0
# 3             regular            2  0.029180      0
# 4  throw-in-set-piece            1  0.018204      0

# %%
from scipy.ndimage import gaussian_filter

attack = df[df["isHome"] == False].copy()

attack = attack.dropna(subset=[
    "playerCoordinates_x",
    "playerCoordinates_y",
    "xg"
])

pitch = Pitch(
    pitch_type='statsbomb',
    line_zorder=2,
    pitch_color='#22312b',
    line_color='#efefef'
)

fig, ax = pitch.draw(figsize=(6.6, 4.125))
fig.set_facecolor('#22312b')

bin_statistic = pitch.bin_statistic(
    attack["playerCoordinates_x"],
    attack["playerCoordinates_y"],
    statistic='sum',
    values=attack["xg"],
    bins=(25, 25)
)

bin_statistic["statistic"] = gaussian_filter(
    bin_statistic["statistic"],
    sigma=1
)

pcm = pitch.heatmap(
    bin_statistic,
    ax=ax,
    cmap='hot',
    edgecolors='#22312b'
)

cbar = fig.colorbar(pcm, ax=ax, shrink=0.6)
cbar.outline.set_edgecolor('#efefef')
cbar.ax.yaxis.set_tick_params(color='#efefef')
plt.setp(
    plt.getp(cbar.ax.axes, 'yticklabels'),
    color='#efefef'
)

ax.set_title(
    "Manchester United – Attacking Danger Heatmap (xG-weighted)\n"
    "LWF: Matheus Cunha | CF: Benjamin Šeško | RWF: Patrick Dorgu",
    
    color='#efefef',
    fontsize=12
)

plt.show()

# %% [markdown]
# ##### *@coded by: Dio Riza Pratama*
